# %%
import json
import io
from io import BytesIO
import os
import pandas as pd
import csv
from csv import reader
import requests
import pycurl
import certifi
import time
from datetime import datetime, date, timedelta
from acrcloud.recognizer import ACRCloudRecognizer
from acrcloud.recognizer import ACRCloudRecognizeType
from bs4 import BeautifulSoup
import shutil
from shutil import copyfile
import pydub
from pydub.playback import play
from pydub import AudioSegment
import ffmpeg
from functools import partial
from itertools import repeat
from itertools import product
import multiprocessing
from multiprocessing import Pool, freeze_support
import glob

# %%
workindir = r'/Users/michaelfelzan/Desktop/GEO FM'


acrcloud_accesskey = '4554490a1c83c19ea6745ed6bfbbea7d'
acrcloud_secretkey = 'HcoVKztgUltoNAwlPxpWoIJzt86HoKk9KTiByPTl'

acrcloud_config = {
    'host':'identify-eu-west-1.acrcloud.com',
    'access_key': acrcloud_accesskey,
    'access_secret': acrcloud_secretkey,
    'recognize_type': ACRCloudRecognizeType.ACR_OPT_REC_AUDIO, # could be 'humming audio' as well
    'debug':False,
    'timeout':5 # seconds
}

ACR_recognizer = ACRCloudRecognizer(acrcloud_config)

# %%
client_key = 'gQylLmyvGPfyGEvmFyRx'
client_secret = 'KJnItkPttweOtFSkqwAiTTCWJsOnIobH'

# %%
os.chdir(r'/Users/michaelfelzan/Desktop/Geography-of-Radio/Data')

# %%
os.getcwd()
# Out:
# '/Users/michaelfelzan/Desktop/Geography-of-Radio/Data'

# %%
os.listdir()
# Out:
# ['MASTER_CSV.csv',
#  'WASH SONG LOGS',
#  'PLACES_DescendingCountriesCSV.csv',
#  '.DS_Store',
#  'WashingtonStations_filled.csv',
#  'sample_mp3_1.mp3',
#  'sample_mp3_2.mp3',
#  'WashingtonStations_OnlyFM.csv',
#  'us_4.csv',
#  'WASH STATIONS',
#  'US_STATIONS_3.csv',
#  'fatal_error_wash.txt',
#  'US_STATIONS.csv',
#  'WashStationInfoTables']

# %%
us3_df = pd.read_csv('US_STATIONS_3.csv')
us3_df.head()
# Out:
#          Country       CityState  City  StateAbv      StationName     RG_ID  \
# 0  United States  Los Angeles CA   NaN       NaN  101 Smooth Jazz  zFDSxGwY
# 1  United States  Los Angeles CA   NaN       NaN            113FM  4KJ_uzy0
# 2  United States  Los Angeles CA   NaN       NaN     88.5 FM KCSN  SsUyqJaN
# 3  United States  Los Angeles CA   NaN       NaN        9128.live  hacyg6SN
# 4  United States  Los Angeles CA   NaN       NaN     98.5 Flex FM  t4dqOINA
#
#                                  RG_LC    CS  \
# 0    /listen/-101-smooth-jazz/zFDSxGwY  xxxx
# 1         /listen/radio-113fm/4KJ_uzy0  xxxx
# 2                /listen/kcsn/SsUyqJaN  KCSN
# 3     /listen/radio-9128-live/hacyg6SN  xxxx
# 4  /listen/radio-98-5-flex-fm/t4dqOINA  xxxx
#
#                                               RG_URL  \
# 0  https://radio.garden/api/ara/content/listen/zF...
# 1  https://radio.garden/api/ara/content/listen/4K...
# 2  https://radio.garden/api/ara/content/listen/Ss...
# 3  https://radio.garden/api/ara/content/listen/ha...
# 4  https://radio.garden/api/ara/content/listen/t4...
#
#                                            URL                CityCords
# 0  https://streaming.live365.com/b22139_128mp3  [-118.24368, 34.052235]
# 1    http://113fm-edge1.cdnstream.com/1730_128  [-118.24368, 34.052235]
# 2                 http://130.166.82.184:8000/;  [-118.24368, 34.052235]
# 3   https://streams.radio.co/s0aa1e6f4a/listen  [-118.24368, 34.052235]
# 4         https://streaming.live365.com/a23768  [-118.24368, 34.052235]

# %% [markdown]
# ## NEXT CELL IS A ONE-TIME RUN TO CREATE A CSV :

# %%
with open('us_4.csv','w',newline='') as csvfile:
    fieldnames = ['Country',
                  'CityState',
                  'City',
                  'StateAbv',
                  'StationName',
                  'RG_ID',
                  'RG_LC',
                  'CS',
                  'RG_URL',
                  'URL',
                  'CityCords']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    with open('US_STATIONS_3.csv', 'r') as read_obj:
        csv_reader = reader(read_obj)
        header = next(csv_reader)
        if header != None:
            for row in csv_reader:
                iter_citystate = row[1]
                iter_split = iter_citystate.split()
                stateabv = iter_split[-1]
                citywspace = iter_citystate.split(stateabv)[0]
                isod_city = citywspace[:-1]
                
                writer.writerow({
                    'Country' : row[0],
                    'CityState' : row[1],
                    'City' : isod_city,
                    'StateAbv' : stateabv,
                    'StationName' : row[4],
                    'RG_ID' : row[5],
                    'RG_LC' : row[6],
                    'CS' : row[7],
                    'RG_URL' : row[8],
                    'URL' : row[9],
                    'CityCords' : row[10]
                })

# %%
WA_FM_CSV = r'/Users/michaelfelzan/Desktop/Geography-of-Radio/Data/WashingtonStations_OnlyFM.csv'

source_CSV = WA_FM_CSV

# %%
failed_wash_infoget = r'/Users/michaelfelzan/Desktop/GEO FM/FailedWashStationsInfoGetter.txt'

# %%
def RadioTowerInfoGetter(callsign):
    """Function that requests the HTML of
    the radio-locator.com webpage for whatever 
    radio station callsign is inputted into the function.
    
    The function parses the HTML to return a dictionary
    containing the radio stations ERP, lat/long,
    HAAT, HAGL, and HASL.
    
    Parameters
    ------------
    callsign : str
        Name of station callsign (eg. KEXP)
    """
    print(f"Attempting to gather info from:  {callsign}...")
    
    radiolocheaders = {
        'sec-ch-ua' : '"Google Chrome";v="89", "Chromium";v="89", ";Not A Brand";v="99"',
        'sec-ch-ua-mobile' : '?0',
        'Upgrade-Insecure-Requests' : '1',
        'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'
    }
    locatorURL_1 = f'https://radio-locator.com/cgi-bin/url?call={callsign}&service=FM'
    locatorURL_2 = f'https://radio-locator.com/cgi-bin/finder?call={callsign}&x=0&y=0&sr=Y&s=C'
    
    radiolocreq = requests.get(locatorURL_1,
                               headers=radiolocheaders)
    stationHTML = radiolocreq.content.decode('utf-8')
    stationsoup = BeautifulSoup(stationHTML)
    techvalues = stationsoup.find_all("td",
                                      class_='tech_value')
    
    if techvalues == []:
        print(f"No radio tower info could be retrieved for station {callsign}")       
        print("Trying other request URL...waiting 20 seconds before retry...")
        time.sleep(20)
        radiolocreq = requests.get(locatorURL_2,
                                   headers=radiolocheaders)
        stationHTML = radiolocreq.content.decode('utf-8')
        stationsoup = BeautifulSoup(stationHTML)
        techvalues = stationsoup.find_all("td",
                                          class_='tech_value')
        if techvalues == []:
            print("Second URL method failed. Stationed logged in 'fails' .txt")
            with open(failed_wash_infoget, "a+") as file_object:
                file_object.seek(0)
                data = file_object.read(100)
                if len(data) > 0 :
                    file_object.write("\n")
                file_object.write(f"{callsign}")
                
            return False
        
        else:
            ERP = []
            coords = []
            heights = []
            # Parsing the HTML:
            for item in techvalues:
                for characters in item:
                    for sub in characters:
                        if '" N' in sub:
                            coords.append(sub)
                if 'Watts' in characters:
                    ERP.append(characters)
                elif 'meters' in characters:
                    heights.append(characters)
                else:
                    pass
    
            try:
                itercoords = coords[0]
            except:
                print("This station didn't have coords data")
                itercoords = 'no_data'
            try:
                iterERP = ERP[0]
            except:
                print("This station didn't have ERP data")
                iterERP = 'no_data'
            try:
                iterHAAT = heights[0]
            except:
                print("This station didn't have HAAT data")
                iterHAAT = 'no_data'
            try:
                iterHAGL = heights[1]
            except:
                print("This station didn't have HAGL data")
                iterHAGL = 'no_data'
            try:
                iterHASL = heights[2]
            except:
                print("This station didn't have HASL data")
                iterHASL = 'no_data'
    
            towerinfo = {
                'ERP' : iterERP,
                'Coords' : itercoords,
                'HAAT' : iterHAAT,
                'Height Above Ground Level' : iterHAGL,
                'Height Above Sea Level' : iterHASL
            }
    
            return towerinfo
    
    else:
        ERP = []
        coords = []
        heights = []
        # Parsing the HTML:
        for item in techvalues:
            for characters in item:
                for sub in characters:
                    if '" N' in sub:
                        coords.append(sub)
            if 'Watts' in characters:
                ERP.append(characters)
            elif 'meters' in characters:
                heights.append(characters)
            else:
                pass
    
        try:
            itercoords = coords[0]
        except:
            print("This station didn't have coords data")
            itercoords = 'no_data'
        try:
            iterERP = ERP[0]
        except:
            print("This station didn't have ERP data")
            iterERP = 'no_data'
        try:
            iterHAAT = heights[0]
        except:
            print("This station didn't have HAAT data")
            iterHAAT = 'no_data'
        try:
            iterHAGL = heights[1]
        except:
            print("This station didn't have HAGL data")
            iterHAGL = 'no_data'
        try:
            iterHASL = heights[2]
        except:
            print("This station didn't have HASL data")
            iterHASL = 'no_data'
    
        towerinfo = {
            'ERP' : iterERP,
            'Coords' : itercoords,
            'HAAT' : iterHAAT,
            'Height Above Ground Level' : iterHAGL,
            'Height Above Sea Level' : iterHASL
        }
    
        towerinfo = {
            'ERP' : iterERP,
            'Coords' : itercoords,
            'HAAT' : iterHAAT,
            'Height Above Ground Level' : iterHAGL,
            'Height Above Sea Level' : iterHASL
        }
    
        return towerinfo

# %%
def StationInfoTxtWriter(stationfolderpath, call_sign):
    """Function that writes the dictionary return
    from RadioTowerInfoGetter() for a station 
    to a .txt file in that station's corresponding
    folder (only if the RadioTowerInfoGetter()
    successfully returns tower info).
    
    Parameters
    ------------
    stationfoldername : str
        Name of a radio stations folder (eg. CA_KALX)
    """
    towerinfodict = RadioTowerInfoGetter(call_sign)
    if towerinfodict == False:
        #print("yes, it failed")
        pass
    else:
        infofilename = os.path.join(stationfolderpath,
                                    f"{call_sign}_towerinfo.txt")
        textyfile = open(infofilename,
                    "w+")
        textyfile.write("{\n")
        for k in towerinfodict.keys():
            textyfile.write("'{}':'{}'\n".format(k, towerinfodict[k]))
        textyfile.write("}")
        textyfile.close()
        print(f"Sucessfully wrote {call_sign}_towerinfo.txt")

# %%
def dms_to_dd(d, m, s):
    """Function that converts degrees minutes seconds
    into decimal degrees.
    
    Parameters
    ------------
    d : str (tho doesnt matter--converted to float in function)
        degree
    m : str (tho doesnt matter--converted to float in function)
        minutes
    s : str (tho doesnt matter--converted to float in function)
        seconds
    """
    dd = d + float(m)/60 + float(s)/3600
    return round(dd, 6)

# %%
def DMS_Isolator(dms_string):
    """function that isolates the degree, minute, and second 
    components  of the DMS return from the StationInfoTxtWriter(),
    so that they may be separately inputted into the
    dms_to_dd() function parameters
    """
    degree = dms_string.split("°")[0]
    minutefirstsplit = dms_string.split("'")[0]
    minute = minutefirstsplit.split("° ")[1]
    secondfirstsplit = dms_string.split('"')[0]
    second = secondfirstsplit.split("' ")[1]
    
    return [degree,minute,second]

# %%
class Station:
    def __init__(self, sourceCSV, callsign):
        self.sourceCSV = sourceCSV
        self.callsign = callsign
        
        with open(sourceCSV, 'r') as read_obj:
            csv_reader = reader(read_obj)
            header = next(csv_reader)
            if header != None:
                for row in csv_reader:
                    if row[7] == callsign:
                        st_country = row[0]
                        st_city = row[2]
                        st_state = row[3]
                        st_url = row[10]
                        st_citycords = row[11]
                        
        self.country = st_country
        self.city = st_city
        self.state = st_state
        self.url = st_url
        self.citycords = st_citycords
        self.txtpath = os.path.join(r'/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS',
                                    callsign,
                                    f'{callsign}.txt')
        self.foldpath = os.path.join(r'/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS',
                                     callsign)
    
    def Sampler(self, url, outpathname):
        audio_input = ffmpeg.input(url)
        audio_output = ffmpeg.output(audio_input,
                                     outpathname,
                                     **{'b:a': '128k'},
                                     ss=35,
                                     t=10)
        #print(audio_output)
        try:
            audio_output.run()
        except:
            print("Error - Sampler could not work on URL stream. Skipping station.")
            return False
    
    def RouteToACRCloud(self, mp3):
        """Function that routes an mp3 file (path) to the
        ACRCloud API, in order to return the song name info.
        
        Parameters
        ------------
        mp3 : str
            Name of mp3 file (path)
            """
        buf = open(mp3,'rb').read()
        # start second will be 0; will record sampled mp3 for 10 seconds
        songread_output = ACR_recognizer.recognize_by_filebuffer(buf, 0)
        return songread_output
    
    
    def RollRadio(self, url, callsign):
        timerightnow = datetime.now()
        formattedtime = timerightnow.strftime("%Y_%m_%d_T%H_%M_%S")
        
        input_stream = url
        input_mp3name = f'{callsign}'+f'{formattedtime}'+'.mp3'
        itersongpath = os.path.join(r'/Users/michaelfelzan/Desktop/GEO FM',
                                    input_mp3name)
        
        print(f'~~Now recording... {input_stream}')
        samplerreturn = self.Sampler(url, itersongpath)
        err = True
        if samplerreturn == False:
            pass
        else:
            acrcloud_output = self.RouteToACRCloud(itersongpath)
            songread_dict = json.loads(acrcloud_output)
    
            if songread_dict['status']['msg'] == 'No result':
                print(f'No ACR return from {input_mp3name}')
                pass
            elif songread_dict['status']['msg'] == 'May Be Mute':
                print(f'No ACR return from {input_mp3name}')
                pass
            elif songread_dict['status']['msg'] == 'Decode Audio Error':
                print(f'No ACR return from {input_mp3name}')
                pass
            elif songread_dict['status']['msg'] == 'requests limit exceeded, please upgrade your account':
                print('ACRCLOUD REQUESTS LIMITS EXCEEDED, STOP PROGRAM')
                pass
            else:
                try:
                    songtitle = songread_dict['metadata']['music'][0]['title']
                except:
                    print("Error in 'Title' ACR return metadata...skipping station")
                    err = False
                if err == False:
                    pass
                else:
                    try:
                        songartist = songread_dict['metadata']['music'][0]['artists'][0]['name']
                    except:
                        print("Error in 'Artist' ACR return metadata...skipping station")
                        err = False
                    if err == False:
                        pass
                    else:
                        try:
                            songalbum = songread_dict['metadata']['music'][0]['album']['name']
                        except:
                            print("Error in 'Album' ACR return metadata...skipping station")
                            err = False
                            pass
                if err == False:
                    pass
                else:
                    ACR_return = f'{input_mp3name} ~ song : {songtitle} by {songartist} from album {songalbum}'
    
                    percent20song = songtitle+'%20'+songartist+'%20'+songalbum
                    discogs_input = percent20song.replace(" ", "%20")
                    discogs_req = ('https://api.discogs.com/database/search?q=' + 
                               discogs_input + 
                               '&key=' + 
                               client_key + 
                               '&secret=' +
                               client_secret)
                    discogs_req_obj = requests.get(discogs_req)
                    discogs_songinfo_dict = json.loads(discogs_req_obj.content.decode('utf-8'))
        
                    if discogs_songinfo_dict['results'] == []:
                        print(f'No Discogs return from {input_mp3name}')
                        pass
                    else:
                        try:
                            style_list = discogs_songinfo_dict['results'][0]['style']
                        except:
                            style_list = 'no_data'
                        try:
                            genre_list = discogs_songinfo_dict['results'][0]['genre']
                        except:
                            genre_list = 'no_data'
                        
                        if style_list == 'no_data':
                            syleliststring = 'no_data'
                        else:
                            styleliststring = ','.join(style_list)
                        if genre_list == 'no_data':
                            genreliststring  = 'no_data'
                        else:
                            genreliststring = ','.join(genre_list)
            
                        Discogs_return = f'Discogs returned the genre(s): {styleliststring}'
                
                        parent_dir = r'/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS'
                
                        itertextpath = os.path.join(parent_dir,
                                                    callsign,
                                                    f'{callsign}.txt')
            
                        with open(itertextpath, "a+") as file_object:
                            file_object.seek(0)
                            data = file_object.read(100)
                            if len(data) > 0 :
                                file_object.write("\n")
                            file_object.write((input_mp3name+
                                               ','+
                                               'song='+songtitle+','+
                                               'artist='+songartist+','+
                                               'album='+songalbum+','+
                                               ####'genres='+genreliststring+','+
                                               'styles='+styleliststring))
                
                        print(f"Returned:{[ACR_return,Discogs_return]}")
                
            os.remove(itersongpath)

# %%
kexptower = RadioTowerInfoGetter('KMRE')
kexptower
# Out:
# Attempting to gather info from:  KMRE...
# No radio tower info could be retrieved for station KMRE
# Trying other request URL...waiting 20 seconds before retry...
# {'ERP': '100 Watts',
#  'Coords': '48° 44\' 51" N, 122° 28\' 45" W',
#  'HAAT': '-13.49 meters (-43 feet)',
#  'Height Above Ground Level': '38.1 meters (125 feet)',
#  'Height Above Sea Level': '65.1 meters (214 feet)'}

# %%
kkxatower = RadioTowerInfoGetter('KKXA')
kkxatower
# Out:
# Attempting to gather info from:  KKXA...
# No radio tower info could be retrieved for station KKXA
# Trying other request URL...waiting 20 seconds before retry...
# This station didn't have HAAT data
# This station didn't have HAGL data
# This station didn't have HASL data
# {'ERP': '50,000 Watts',
#  'Coords': '47° 52\' 31" N, 122° 04\' 44" W',
#  'HAAT': 'no_data',
#  'Height Above Ground Level': 'no_data',
#  'Height Above Sea Level': 'no_data'}

# %%
fails_txt = r'/Users/michaelfelzan/Desktop/GEO FM/FailedWashStationsInfoGetter.txt'
fails_list = []

with open(fails_txt, "r") as a_file:
    for line in a_file:
        stripped_line = line.strip()
        fails_list.append(stripped_line)

# %%
fails_list
# Out:
# ['KOWA', 'KORE', 'KVSH']

# %% [markdown]
# #### One-time use code for deleting all text files !! :

# %%
#parent_dir = r'/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS'

#for washcallsign in list_of_wash_callsigns:
    #iter_station = Station(WA_FM_CSV, washcallsign)
    #itertextpath = os.path.join(parent_dir,
                               #washcallsign,
                               #f'{washcallsign}.txt')
    #os.remove(itertextpath)

# %% [markdown]
# ##### Creating 'list_of_wash_callsigns;' appending all names of Washington callsigns to list:

# %%
list_of_wash_callsigns = []

with open(source_CSV, 'r') as read_obj:
    csv_reader = reader(read_obj)
    header = next(csv_reader)
    if header != None:
        for row in csv_reader:
            iter_callsign = row[7]
            list_of_wash_callsigns.append(iter_callsign)

# %% [markdown]
# ##### Making folder directories for all Washington callsigns:

# %%
for washcallsign in list_of_wash_callsigns:
    iter_station = Station(WA_FM_CSV, washcallsign)
    # Directory 
    directory_name = iter_station.callsign
    
    # Parent Directory path
    parent_dir = r'/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS'
    
    # Path 
    foldpath = os.path.join(parent_dir, directory_name)

    # Create the directory 
    os.mkdir(foldpath)

# %% [markdown]
# ##### Creating .txt files for all Washington callsigns in correct format:

# %%
for washcallsign in list_of_wash_callsigns:
    itertextpath = os.path.join(parent_dir,
                               washcallsign,
                               f'{washcallsign}.txt')
    #print(itertextpath)
    
    with open(itertextpath, "w") as f:
        f.write(f'{washcallsign}')
    
    
for washcallsign in list_of_wash_callsigns:
    iter_station = Station(WA_FM_CSV,
                           washcallsign)
    itertextpath = os.path.join(parent_dir,
                               washcallsign,
                               f'{washcallsign}.txt')
    with open(itertextpath, "a+") as file_object:
        file_object.seek(0)
        # If file is not empty then append '\n'
        data = file_object.read(100)
        if len(data) > 0 :
            file_object.write("\n")
        # Append text at the end of file
        file_object.write(f"stream={iter_station.url}")
        file_object.write("\n")

# %%
parent_dir = r'/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS'

for cs in fails_list:
    
    iterfoldpathy = os.path.join(parent_dir,
                                cs)
    # StationInfoTxtWriter(stationfolderpath, call_sign):
    StationInfoTxtWriter(iterfoldpathy,
                         cs)
    time.sleep(20)

# %%
parent_dir = r'/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS'
os.chdir(parent_dir)
wash_callsign_folds = []
for thing in os.listdir():
    if thing == '.DS_Store':
        pass
    else:
        wash_callsign_folds.append(thing)

# %%
wash_callsign_folds
# Out:
# ['KPBX',
#  'KHUH',
#  'KACS',
#  'KYRS',
#  'KXDD',
#  'KZAX',
#  'KMRE',
#  'KFAE',
#  'KUKN',
#  'KOSW',
#  'KTQA',
#  'KBCS',
#  'KZTM',
#  'KEZE',
#  'KPLW',
#  'KROH',
#  'KGHI',
#  'KUPS',
#  'KIEV',
#  'KSQM',
#  'KAOS',
#  'KMIH',
#  'KPBZ',
#  'KTAH',
#  'KEFA',
#  'KSER',
#  'KNKX',
#  'KUOW',
#  'KIRO',
#  'KGRG',
#  'KEWU',
#  'KDDS',
#  'KWCW',
#  'KNHC',
#  'KEXP',
#  'KZZU',
#  'KZQM',
#  'KUGS',
#  'KPTZ',
#  'KBFG',
#  'KXLY',
#  'KODX',
#  'KGHP',
#  'KING',
#  'KYYO',
#  'KEGX',
#  'KCMS']

# %%
os.chdir(r'/Users/michaelfelzan/Desktop/GEO FM')
os.getcwd()
# Out:
# '/Users/michaelfelzan/Desktop/GEO FM'

# %%
stream = os.popen('node fezCC.js 4.7 211 "250" "-" 60 "0"')
output = (stream.read()).split('\n')[0]
output
# Out:
# '37.699469101964276'

# %%
for cs in wash_callsign_folds:
    pathtostationfold = os.path.join(parent_dir,
                                    cs)
    #itercallsign = station.split("_")[1]
    #stateabv = station.split("_")[0]
    pathtotowertxt = os.path.join(pathtostationfold,
                            f'{cs}_towerinfo.txt')
    pathtotxt = os.path.join(pathtostationfold,
                             f'{cs}.txt')
    newinfocsv = os.path.join(pathtostationfold,
                             f'{cs}_INFO.csv')
    stationfolditems = os.listdir(pathtostationfold)
    fullpathitems = []
    for item in stationfolditems:
        fullpathitems.append(os.path.join(pathtostationfold,
                                         item))
    if pathtotowertxt in fullpathitems:
        with open(pathtotowertxt) as foo:
            txtz = foo.readlines()
            for item in txtz:
                
                if 'ERP' in item:
                    wattsfirstsplit = item.split(":'")[1]
                    watts = wattsfirstsplit.split(" Watts")[0]
                    kilowatts = (float(watts.replace(',','')))/1000
                    
                elif 'Coords' in item:
                    coordsfirstsplit = item.split(":'")[1]
                    lat_dms = coordsfirstsplit.split(",")[0]
                    long_dms = (coordsfirstsplit.split(", ")[1])[:-2]
                    
                    lat_dms_list = DMS_Isolator(lat_dms)
                    long_dms_list = DMS_Isolator(long_dms)
                    
                    lat_dd = dms_to_dd(float(lat_dms_list[0]),
                                       float(lat_dms_list[1]),
                                       float(lat_dms_list[2]))
                    long_dd = dms_to_dd(float(long_dms_list[0]),
                                        float(long_dms_list[1]),
                                        float(long_dms_list[2]))
                    negative_longdd = long_dd*-1
                    
                elif 'HAAT' in item:
                    HAATfirstsplit = item.split(":'")[1]
                    HAAT_clean = HAATfirstsplit.split(" meters")[0]
                    HAAT_float = float(HAAT_clean)
        
                    stream_param = f'node fezCC.js {kilowatts} {HAAT_float} "250" "-" 60 "0"'
                    stream = os.popen(stream_param)
                    BUFF60DIST = (stream.read()).split('\n')[0]
                
        with open(newinfocsv,'w',newline='') as csvfile:
            fieldnames = ['CALLSIGN',
                          'LAT',
                          'LONG',
                          'ERP',
                          'HAAT',
                          '60dBu_DIST']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerow({
                'CALLSIGN': cs,
                'LAT' : lat_dd,
                'LONG' : negative_longdd,
                'ERP' : kilowatts,
                'HAAT' : HAAT_clean,
                '60dBu_DIST' : BUFF60DIST
            })
                
    else:
        print(f'tower info .txt does not exist for {cs}')
        pass

print("\n     *~*~~~~~**~~~~~~~~~~~~~~**~*~*\n"+
      "Successfully wrote all other station tower info CSVs."+
      "\nCSVs outputted to respective station folders."
      "\n   *~*~~~~~**~~~~~~~~~~~~~~**~*~*")

# %%
stationinfopath = os.path.join(r'/Users/michaelfelzan/Desktop/GEO FM',
                               "WashStationInfoTables")
os.mkdir(stationinfopath)

# %%
# COPYING FILES TO StationInfoTables FOLDER

for cs in wash_callsign_folds:
    pathtostationfold = os.path.join(parent_dir,
                                    cs,)
    newinfocsv = os.path.join(pathtostationfold,
                             f'{cs}_INFO.csv')
    stationfolditems = os.listdir(pathtostationfold)
    fullpathitems = []
    for item in stationfolditems:
        fullpathitems.append(os.path.join(pathtostationfold,
                                         item))
    if newinfocsv in fullpathitems:
        copyfile(newinfocsv,
                 os.path.join(r'/Users/michaelfelzan/Desktop/GEO FM',
                              "WashStationInfoTables",
                              f'{cs}_INFO.csv'))

# %%
pathtofold = r'/Users/michaelfelzan/Desktop/GEO FM/WashStationInfoTables'
INFOconcatCSV = os.path.join(pathtofold,
                             "WASHSTATIONINFOconcat.csv") 
allFiles = glob.glob(pathtofold + "/*.csv")
allFiles.sort()
with open(INFOconcatCSV, 'wb') as outfile:
        for i, fname in enumerate(allFiles):
            with open(fname, 'rb') as infile:
                if i != 0:
                    infile.readline()  # Throw away header on all but first file
            # Block copy rest of file from input to output without parsing
                shutil.copyfileobj(infile, outfile)

print("     *~*~~~~~**~~~~~~~~~~~~~~**~*~*\n"
      "All station tower info CSVs (that exist) have"+
      "\n      been successfully merged together"
      "\n  *~*~~~~~**~~~~~~~~~~~~~~**~*~*")

# %%
wash_stn_info_concat = os.path.join(r'/Users/michaelfelzan/Desktop/GEO FM',
                                    "WashStationInfoTables",
                                    "WASHSTATIONINFOconcat.csv")

wash_stn_info_df = pd.read_csv(wash_stn_info_concat)
wash_stn_info_df
# Out:
#    CALLSIGN        LAT        LONG      ERP    HAAT  60dBu_DIST
# 0      KACS  46.730556 -123.025833    6.000   57.00   21.947963
# 1      KAOS  47.015833 -122.917222    1.250   74.00   16.686530
# 2      KBCS  47.543889 -122.109167    1.800  389.00   40.247137
# 3      KBFG  47.667500 -122.355000    0.009   95.94    5.546802
# 4      KCMS  47.544167 -122.108333   54.000  385.00   72.279685
# 5      KDDS  47.312500 -123.372222   64.000  742.00   92.461470
# 6      KEFA  47.382778 -120.293333    0.100  -71.00    5.636485
# 7      KEGX  46.099167 -119.128889  100.000  424.40   81.532897
# 8      KEWU  47.578611 -117.298333   10.000  429.00   57.879066
# 9      KEXP  47.615833 -122.308889    4.700  211.00   37.699469
# 10     KEZE  47.725833 -117.169444    8.200  365.00   52.411102
# 11     KFAE  46.095000 -119.195833  100.000  350.00   76.082001
# 12     KGHI  46.919444 -123.955278    1.900   18.00   11.860072
# 13     KGHP  47.240556 -122.772222    1.350   61.00   15.402396
# 14     KGRG  47.256111 -122.219722    0.230  116.00   13.549143
# 15     KHUH  47.613056 -122.305000    0.015   78.00    5.677022
# 16     KIEV  45.656111 -122.385556    0.100   30.00    5.636485
# 17     KING  47.503611 -121.975833   66.000  707.00   91.525059
# 18     KIRO  47.503611 -121.975833   52.000  729.00   89.847959
# 19     KMIH  47.572222 -122.219167    0.030   69.00    6.308638
# 20     KMRE  48.747500 -122.479167    0.100  -13.49    5.636485
# 21     KNHC  47.542778 -122.108056    8.500  372.00   53.157927
# 22     KNKX  47.503611 -121.975833   64.000  707.00   91.207351
# 23     KODX  47.659167 -122.312222    0.038   48.50    5.608430
# 24     KOSW  46.984167 -124.153889    0.076   35.23    5.651727
# 25     KPBX  47.570278 -117.084444   56.000  725.00   90.470883
# 26     KPBZ  47.813333 -117.507500    0.550  329.70   28.409386
# 27     KPLW  47.323333 -120.234444    7.000  424.00   54.193125
# 28     KPTZ  48.128056 -122.828889    2.200  102.00   22.779632
# 29     KROH  48.015833 -122.926111    1.150  456.00   39.510279
# 30     KSER  48.024167 -122.112500    5.800   92.00   26.994633
# 31     KSQM  48.083333 -123.267222    2.050  -62.00   12.075181
# 32     KTAH  47.221389 -122.469722    0.016   69.11    5.429665
# 33     KTQA  47.239167 -122.446111    0.019   69.00    5.659309
# 34     KUGS  48.735556 -122.482778    0.810  137.00   20.608062
# 35     KUKN  46.162778 -122.854722    0.700  256.00   26.620990
# 36     KUOW  47.615833 -122.308889  100.000  224.00   66.029465
# 37     KUPS  47.263056 -122.478056    0.100   70.00    8.638738
# 38     KWCW  46.069444 -118.331944    0.160  -16.00    6.340287
# 39     KXDD  46.513056 -120.402500  100.000  245.00   67.828095
# 40     KXLY  47.921667 -117.114444   37.000  914.00   91.897985
# 41     KYRS  48.180556 -117.987500    6.800  876.00   72.624184
# 42     KYYO  47.085556 -123.189444   11.000  321.00   52.353900
# 43     KZAX  48.747500 -122.479167    0.100  -17.49    5.636485
# 44     KZQM  48.125833 -123.117222    6.000   22.00   15.752658
# 45     KZTM  46.975000 -123.140556   70.000  668.00   90.709301
# 46     KZZU  47.595000 -117.299167   81.000  634.00   90.941259

# %%
#while True:
    #for cs in wash_callsign_folds:
        #iter_satysh = Station(WA_FM_CSV, cs)
        #iter_satysh.RollRadio(iter_satysh.url,
                             # iter_satysh.callsign)

# %%
KACS = Station(WA_FM_CSV, 'KACS')
KZZU = Station(WA_FM_CSV, 'KZZU')
KEXP = Station(WA_FM_CSV, 'KEXP')
KYRS = Station(WA_FM_CSV, 'KYRS')

# %%
print(KEXP.txtpath)
# Out:
# /Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS/KEXP/KEXP.txt

# %%
wash_url_cs_tuples = []

for cs in wash_callsign_folds:
    globals()[f'{cs}'] = Station(WA_FM_CSV, cs)
    wash_url_cs_tuples.append( ( globals()[f'{cs}'].url,
                                globals()[f'{cs}'].callsign) )

wash_url_cs_tuples
# Out:
# [('https://18733.live.streamtheworld.com/KPBX_FM.mp3', 'KPBX'),
#  ('http://centova.rockhost.com:8001/stream', 'KHUH'),
#  ('https://ic2.sslstream.com/kacs-fm', 'KACS'),
#  ('https://www.ophanim.net:8444/s/7170', 'KYRS'),
#  ('https://ice7.securenetsystems.net/KXDD', 'KXDD'),
#  ('http://199.180.75.2:9395/stream/;', 'KZAX'),
#  ('http://199.180.75.2:9391/;', 'KMRE'),
#  ('http://134.121.234.129:8000/NWPRCLASSICAL', 'KFAE'),
#  ('http://www.streamcontrol.net:11060/;', 'KUKN'),
#  ('http://ophanim.net:7040/;', 'KOSW'),
#  ('https://stream.ktqa.org/ktqa.mp3', 'KTQA'),
#  ('http://www.ophanim.net:7720/stream', 'KBCS'),
#  ('http://bustosradio.com:8039/kztm', 'KZTM'),
#  ('https://17963.live.streamtheworld.com/KEZEFMAAC.aac', 'KEZE'),
#  ('https://ice10.securenetsystems.net/PLR', 'KPLW'),
#  ('https://ice10.securenetsystems.net/KROH', 'KROH'),
#  ('http://173.193.205.96:7341/stream', 'KGHI'),
#  ('https://streamingv2.shoutcast.com/kupsfm', 'KUPS'),
#  ('https://usa17.fastcast4u.com/proxy/kievradio?mp=/1', 'KIEV'),
#  ('https://video1.getstreamhosting.com:8182/stream', 'KSQM'),
#  ('http://205.134.192.90:8930/;', 'KAOS'),
#  ('https://www.streamvortex.com:8444/s/11390', 'KMIH'),
#  ('https://24883.live.streamtheworld.com/KPBZ_FM.mp3', 'KPBZ'),
#  ('https://stream.radiotacoma.org/ktah.mp3', 'KTAH'),
#  ('https://www.streamvortex.com:8444/s/11160', 'KEFA'),
#  ('http://jade.streamguys1.com:4050/live', 'KSER'),
#  ('https://live.wostreaming.net/direct/ppm-knkxfmaac256-ibc1', 'KNKX'),
#  ('https://15363.live.streamtheworld.com/KUOWFM_HIGH_MP3.mp3', 'KUOW'),
#  ('https://playerservices.streamtheworld.com/api/livestream-redirect/KIROFM.mp3',
#   'KIRO'),
#  ('http://204.141.167.19:7090/stream?1573141452215.mp3', 'KGRG'),
#  ('https://kewuradio.ewu.edu/KEWU_Jazz_89.5', 'KEWU'),
#  ('http://bustosradio.com:8031/kdds', 'KDDS'),
#  ('http://shoutcast.whitman.edu:8000/;', 'KWCW'),
#  ('http://knhc-ice.streamguys1.com/live', 'KNHC'),
#  ('https://kexp-mp3-128.streamguys1.com/kexp128.mp3', 'KEXP'),
#  ('https://15373.live.streamtheworld.com/KZZUFMAAC_SC', 'KZZU'),
#  ('https://crystalout.surfernetwork.com:8001/KZQM-FM_MP3', 'KZQM'),
#  ('http://peridot.streamguys.com:7170/kugs-mp3', 'KUGS'),
#  ('https://kptz.streamguys1.com/live-mp3', 'KPTZ'),
#  ('http://192.81.134.38:8001/kbfg-2', 'KBFG'),
#  ('https://13693.live.streamtheworld.com/KXLYFMAAC.aac', 'KXLY'),
#  ('https://stream.pacificaservice.org:9000/kodx', 'KODX'),
#  ('https://ic1.mainstreamnetwork.com/kghp-fm', 'KGHP'),
#  ('https://classicalking.streamguys1.com/king-fm-aac-128k', 'KING'),
#  ('http://stream1.noctel.com:7003/969kayo', 'KYYO'),
#  ('https://ice5.securenetsystems.net/KEGX', 'KEGX'),
#  ('https://crista-kcms.streamguys1.com/kcmsmp3', 'KCMS')]

# %%
def multi_run_wrapper(args):
    return RadioRoller(*args)
def RadioRoller(url, callsign):
    return (globals()[f'{callsign}']).RollRadio(globals()[f'{callsign}'].url,
                                               globals()[f'{callsign}'].callsign)
if __name__ == "__main__":
    #multiprocessing.set_start_method('spawn')
    pool = multiprocessing.Pool(processes=3, maxtasksperchild=1)
    startcycletime = datetime.time(datetime.now())
    timecounter = 0
    while timecounter < 899:
        pool.map(multi_run_wrapper,
                 wash_url_cs_tuples,
                chunksize=1)
        endcycletime = datetime.time(datetime.now())
        runduration = datetime.combine(date.today(), endcycletime) - datetime.combine(date.today(), startcycletime)
        rundur_sec = runduration.seconds
        if rundur_sec < 300:
            print(f'finished sampling batch of stations...waiting {300-rundur_sec} seconds...')
            time.sleep(300 - rundur_sec)
            timecounter += 300
# Out:
# ~~Now recording... https://18733.live.streamtheworld.com/KPBX_FM.mp3
# ~~Now recording... http://centova.rockhost.com:8001/stream
# ~~Now recording... https://ic2.sslstream.com/kacs-fm
# ~~Now recording... https://usa17.fastcast4u.com/proxy/kievradio?mp=/1

# %%
help(multiprocessing)
# Out:
# Help on package multiprocessing:
#
# NAME
#     multiprocessing
#
# MODULE REFERENCE
#     https://docs.python.org/3.7/library/multiprocessing
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     # Package analogous to 'threading.py' but using processes
#     #
#     # multiprocessing/__init__.py
#     #
#     # This package is intended to duplicate the functionality (and much of
#     # the API) of threading.py but uses processes instead of threads.  A
#     # subpackage 'multiprocessing.dummy' has the same API but is a simple
#     # wrapper for 'threading'.
#     #
#     # Copyright (c) 2006-2008, R Oudkerk
#     # Licensed to PSF under a Contributor Agreement.
#     #
#
# PACKAGE CONTENTS
#     connection
#     context
#     dummy (package)
#     forkserver
#     heap
#     managers
#     pool
#     popen_fork
#     popen_forkserver
#     popen_spawn_posix
#     popen_spawn_win32
#     process
#     queues
#     reduction
#     resource_sharer
#     semaphore_tracker
#     sharedctypes
#     spawn
#     synchronize
#     util
#
# SUBMODULES
#     reducer
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         multiprocessing.context.ProcessError
#             multiprocessing.context.AuthenticationError
#             multiprocessing.context.BufferTooShort
#             multiprocessing.context.TimeoutError
#     multiprocessing.process.BaseProcess(builtins.object)
#         multiprocessing.context.Process
#
#     class AuthenticationError(ProcessError)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      AuthenticationError
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class BufferTooShort(ProcessError)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      BufferTooShort
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class Process(multiprocessing.process.BaseProcess)
#      |  Process(group=None, target=None, name=None, args=(), kwargs={}, *, daemon=None)
#      |
#      |  Process objects represent activity that is run in a separate process
#      |
#      |  The class is analogous to `threading.Thread`
#      |
#      |  Method resolution order:
#      |      Process
#      |      multiprocessing.process.BaseProcess
#      |      builtins.object
#      |
#      |  Methods inherited from multiprocessing.process.BaseProcess:
#      |
#      |  __init__(self, group=None, target=None, name=None, args=(), kwargs={}, *, daemon=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  close(self)
#      |      Close the Process object.
#      |
#      |      This method releases resources held by the Process object.  It is
#      |      an error to call this method if the child process is still running.
#      |
#      |  is_alive(self)
#      |      Return whether process is alive
#      |
#      |  join(self, timeout=None)
#      |      Wait until child process terminates
#      |
#      |  kill(self)
#      |      Terminate process; sends SIGKILL signal or uses TerminateProcess()
#      |
#      |  run(self)
#      |      Method to be run in sub-process; can be overridden in sub-class
#      |
#      |  start(self)
#      |      Start child process
#      |
#      |  terminate(self)
#      |      Terminate process; sends SIGTERM signal or uses TerminateProcess()
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from multiprocessing.process.BaseProcess:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  authkey
#      |
#      |  daemon
#      |      Return whether process is a daemon
#      |
#      |  exitcode
#      |      Return exit code of process or `None` if it has yet to stop
#      |
#      |  ident
#      |      Return identifier (PID) of process or `None` if it has yet to start
#      |
#      |  name
#      |
#      |  pid
#      |      Return identifier (PID) of process or `None` if it has yet to start
#      |
#      |  sentinel
#      |      Return a file descriptor (Unix) or handle (Windows) suitable for
#      |      waiting for process termination.
#
#     class ProcessError(builtins.Exception)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class TimeoutError(ProcessError)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      TimeoutError
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
# FUNCTIONS
#     Array(typecode_or_type, size_or_initializer, *, lock=True) method of multiprocessing.context.DefaultContext instance
#         Returns a synchronized shared array
#
#     Barrier(parties, action=None, timeout=None) method of multiprocessing.context.DefaultContext instance
#         Returns a barrier object
#
#     BoundedSemaphore(value=1) method of multiprocessing.context.DefaultContext instance
#         Returns a bounded semaphore object
#
#     Condition(lock=None) method of multiprocessing.context.DefaultContext instance
#         Returns a condition object
#
#     Event() method of multiprocessing.context.DefaultContext instance
#         Returns an event object
#
#     JoinableQueue(maxsize=0) method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     Lock() method of multiprocessing.context.DefaultContext instance
#         Returns a non-recursive lock object
#
#     Manager() method of multiprocessing.context.DefaultContext instance
#         Returns a manager associated with a running server process
#
#         The managers methods such as `Lock()`, `Condition()` and `Queue()`
#         can be used to create shared objects.
#
#     Pipe(duplex=True) method of multiprocessing.context.DefaultContext instance
#         Returns two connection object connected by a pipe
#
#     Pool(processes=None, initializer=None, initargs=(), maxtasksperchild=None) method of multiprocessing.context.DefaultContext instance
#         Returns a process pool object
#
#     Queue(maxsize=0) method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     RLock() method of multiprocessing.context.DefaultContext instance
#         Returns a recursive lock object
#
#     RawArray(typecode_or_type, size_or_initializer) method of multiprocessing.context.DefaultContext instance
#         Returns a shared array
#
#     RawValue(typecode_or_type, *args) method of multiprocessing.context.DefaultContext instance
#         Returns a shared object
#
#     Semaphore(value=1) method of multiprocessing.context.DefaultContext instance
#         Returns a semaphore object
#
#     SimpleQueue() method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     Value(typecode_or_type, *args, lock=True) method of multiprocessing.context.DefaultContext instance
#         Returns a synchronized shared object
#
#     active_children()
#         Return list of process objects corresponding to live child processes
#
#     allow_connection_pickling() method of multiprocessing.context.DefaultContext instance
#         Install support for sending connections and sockets
#         between processes
#
#     cpu_count() method of multiprocessing.context.DefaultContext instance
#         Returns the number of CPUs in the system
#
#     current_process()
#         Return process object representing the current process
#
#     freeze_support() method of multiprocessing.context.DefaultContext instance
#         Check whether this is a fake forked process in a frozen executable.
#         If so then run code specified by commandline and exit.
#
#     get_all_start_methods() method of multiprocessing.context.DefaultContext instance
#
#     get_context(method=None) method of multiprocessing.context.DefaultContext instance
#
#     get_logger() method of multiprocessing.context.DefaultContext instance
#         Return package logger -- if it does not already exist then
#         it is created.
#
#     get_start_method(allow_none=False) method of multiprocessing.context.DefaultContext instance
#
#     log_to_stderr(level=None) method of multiprocessing.context.DefaultContext instance
#         Turn on logging and add a handler which prints to stderr
#
#     set_executable(executable) method of multiprocessing.context.DefaultContext instance
#         Sets the path to a python.exe or pythonw.exe binary used to run
#         child processes instead of sys.executable when using the 'spawn'
#         start method.  Useful for people embedding Python.
#
#     set_forkserver_preload(module_names) method of multiprocessing.context.DefaultContext instance
#         Set list of module names to try to load in forkserver process.
#         This is really just a hint.
#
#     set_start_method(method, force=False) method of multiprocessing.context.DefaultContext instance
#
# DATA
#     __all__ = ['Array', 'AuthenticationError', 'Barrier', 'BoundedSemaphor...
#
# FILE
#     /opt/anaconda3/lib/python3.7/multiprocessing/__init__.py

# %%
for tup in wash_url_cs_tuples:
    print(tup[1], tup[0])
# Out:
# KPBX https://18733.live.streamtheworld.com/KPBX_FM.mp3
# KHUH http://centova.rockhost.com:8001/stream
# KACS https://ic2.sslstream.com/kacs-fm
# KYRS https://www.ophanim.net:8444/s/7170
# KXDD https://ice7.securenetsystems.net/KXDD
# KZAX http://199.180.75.2:9395/stream/;
# KMRE http://199.180.75.2:9391/;
# KFAE http://134.121.234.129:8000/NWPRCLASSICAL
# KUKN http://www.streamcontrol.net:11060/;
# KOSW http://ophanim.net:7040/;
# KTQA https://stream.ktqa.org/ktqa.mp3
# KBCS http://www.ophanim.net:7720/stream
# KZTM http://bustosradio.com:8039/kztm
# KEZE https://17963.live.streamtheworld.com/KEZEFMAAC.aac
# KPLW https://ice10.securenetsystems.net/PLR
# KROH https://ice10.securenetsystems.net/KROH
# KGHI http://173.193.205.96:7341/stream
# KUPS https://streamingv2.shoutcast.com/kupsfm
# KIEV https://usa17.fastcast4u.com/proxy/kievradio?mp=/1
# KSQM https://video1.getstreamhosting.com:8182/stream
# KAOS http://205.134.192.90:8930/;
# KMIH https://www.streamvortex.com:8444/s/11390
# KPBZ https://24883.live.streamtheworld.com/KPBZ_FM.mp3
# KTAH https://stream.radiotacoma.org/ktah.mp3
# KEFA https://www.streamvortex.com:8444/s/11160
# KSER http://jade.streamguys1.com:4050/live
# KNKX https://live.wostreaming.net/direct/ppm-knkxfmaac256-ibc1
# KUOW https://15363.live.streamtheworld.com/KUOWFM_HIGH_MP3.mp3
# KIRO https://playerservices.streamtheworld.com/api/livestream-redirect/KIROFM.mp3
# KGRG http://204.141.167.19:7090/stream?1573141452215.mp3
# KEWU https://kewuradio.ewu.edu/KEWU_Jazz_89.5
# KDDS http://bustosradio.com:8031/kdds
# KWCW http://shoutcast.whitman.edu:8000/;
# KNHC http://knhc-ice.streamguys1.com/live
# KEXP https://kexp-mp3-128.streamguys1.com/kexp128.mp3
# KZZU https://15373.live.streamtheworld.com/KZZUFMAAC_SC
# KZQM https://crystalout.surfernetwork.com:8001/KZQM-FM_MP3
# KUGS http://peridot.streamguys.com:7170/kugs-mp3
# KPTZ https://kptz.streamguys1.com/live-mp3
# KBFG http://192.81.134.38:8001/kbfg-2
# KXLY https://13693.live.streamtheworld.com/KXLYFMAAC.aac
# KODX https://stream.pacificaservice.org:9000/kodx
# KGHP https://ic1.mainstreamnetwork.com/kghp-fm
# KING https://classicalking.streamguys1.com/king-fm-aac-128k
# KYYO http://stream1.noctel.com:7003/969kayo
# KEGX https://ice5.securenetsystems.net/KEGX
# KCMS https://crista-kcms.streamguys1.com/kcmsmp3

# %%
for tup in wash_url_cs_tuples:
    it_staysh = Station(WA_FM_CSV, tup[1])
    it_staysh.RollRadio(it_staysh.url, it_staysh.callsign)
# Out:
# ~~Now recording... https://18733.live.streamtheworld.com/KPBX_FM.mp3
# No ACR return from KPBX2021_11_03_T10_29_40.mp3
# ~~Now recording... http://centova.rockhost.com:8001/stream
# Returned:['KHUH2021_11_03_T10_30_17.mp3 ~ song : Dust Bunnies by Kurt Vile from album Dust Bunnies', 'Discogs returned the genre(s): Indie Rock']
# ~~Now recording... https://ic2.sslstream.com/kacs-fm
# No Discogs return from KACS2021_11_03_T10_30_59.mp3
# ~~Now recording... https://www.ophanim.net:8444/s/7170
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://ice7.securenetsystems.net/KXDD
# No ACR return from KXDD2021_11_03_T10_31_31.mp3
# ~~Now recording... http://199.180.75.2:9395/stream/;
# No ACR return from KZAX2021_11_03_T10_32_04.mp3
# ~~Now recording... http://199.180.75.2:9391/;
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://134.121.234.129:8000/NWPRCLASSICAL
# No ACR return from KFAE2021_11_03_T10_32_34.mp3
# ~~Now recording... http://www.streamcontrol.net:11060/;
# No ACR return from KUKN2021_11_03_T10_33_17.mp3
# ~~Now recording... http://ophanim.net:7040/;
# Returned:['KOSW2021_11_03_T10_33_47.mp3 ~ song : Levon by Elton John from album Madman Across The Water', 'Discogs returned the genre(s): Pop Rock,Classic Rock']
# ~~Now recording... https://stream.ktqa.org/ktqa.mp3
# No ACR return from KTQA2021_11_03_T10_34_18.mp3
# ~~Now recording... http://www.ophanim.net:7720/stream
# No ACR return from KBCS2021_11_03_T10_34_54.mp3
# ~~Now recording... http://bustosradio.com:8039/kztm
# No Discogs return from KZTM2021_11_03_T10_35_11.mp3
# ~~Now recording... https://17963.live.streamtheworld.com/KEZEFMAAC.aac
# No Discogs return from KEZE2021_11_03_T10_35_53.mp3
# ~~Now recording... https://ice10.securenetsystems.net/PLR
# Returned:['KPLW2021_11_03_T10_36_32.mp3 ~ song : Good God Almighty by Crowder from album Good God Almighty', 'Discogs returned the genre(s): ']
# ~~Now recording... https://ice10.securenetsystems.net/KROH
# No ACR return from KROH2021_11_03_T10_37_09.mp3
# ~~Now recording... http://173.193.205.96:7341/stream
# No Discogs return from KGHI2021_11_03_T10_37_48.mp3
# ~~Now recording... https://streamingv2.shoutcast.com/kupsfm
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://usa17.fastcast4u.com/proxy/kievradio?mp=/1
# No Discogs return from KIEV2021_11_03_T10_38_22.mp3
# ~~Now recording... https://video1.getstreamhosting.com:8182/stream
# Returned:['KSQM2021_11_03_T10_39_03.mp3 ~ song : Am I Blue by Linda Ronstadt from album Am I Blue', 'Discogs returned the genre(s): Easy Listening']
# ~~Now recording... http://205.134.192.90:8930/;
# Returned:['KAOS2021_11_03_T10_39_45.mp3 ~ song : The Way To Gone by Black Mountain from album Wilderness Heart', 'Discogs returned the genre(s): Blues Rock,Stoner Rock,Psychedelic Rock,Indie Rock']
# ~~Now recording... https://www.streamvortex.com:8444/s/11390
# Returned:['KMIH2021_11_03_T10_40_15.mp3 ~ song : Shallow by Lady Gaga from album Shallow', 'Discogs returned the genre(s): Ballad,Country Rock']
# ~~Now recording... https://24883.live.streamtheworld.com/KPBZ_FM.mp3
# No ACR return from KPBZ2021_11_03_T10_40_46.mp3
# ~~Now recording... https://stream.radiotacoma.org/ktah.mp3
# Returned:['KTAH2021_11_03_T10_41_23.mp3 ~ song : No One Else by Ida Bay from album Ida Bay', 'Discogs returned the genre(s): Big Band,Swing']
# ~~Now recording... https://www.streamvortex.com:8444/s/11160
# No ACR return from KEFA2021_11_03_T10_41_59.mp3
# ~~Now recording... http://jade.streamguys1.com:4050/live
# No ACR return from KSER2021_11_03_T10_42_29.mp3
# ~~Now recording... https://live.wostreaming.net/direct/ppm-knkxfmaac256-ibc1
# No ACR return from KNKX2021_11_03_T10_43_08.mp3
# ~~Now recording... https://15363.live.streamtheworld.com/KUOWFM_HIGH_MP3.mp3
# No ACR return from KUOW2021_11_03_T10_43_44.mp3
# ~~Now recording... https://playerservices.streamtheworld.com/api/livestream-redirect/KIROFM.mp3
# No ACR return from KIRO2021_11_03_T10_44_23.mp3
# ~~Now recording... http://204.141.167.19:7090/stream?1573141452215.mp3
# No ACR return from KGRG2021_11_03_T10_45_06.mp3
# ~~Now recording... https://kewuradio.ewu.edu/KEWU_Jazz_89.5
# Returned:['KEWU2021_11_03_T10_45_38.mp3 ~ song : I Love Being Here With You by Ernestine Anderson from album Great Moments with Ernestine Anderson', 'Discogs returned the genre(s): Vocal']
# ~~Now recording... http://bustosradio.com:8031/kdds
# No ACR return from KDDS2021_11_03_T10_46_23.mp3
# ~~Now recording... http://shoutcast.whitman.edu:8000/;
# Returned:['KWCW2021_11_03_T10_47_05.mp3 ~ song : Station by Alex G from album Beach Music', 'Discogs returned the genre(s): Indie Rock,Lo-Fi']
# ~~Now recording... http://knhc-ice.streamguys1.com/live
# Returned:["KNHC2021_11_03_T10_47_34.mp3 ~ song : I'm Not Alone by Calvin Harris from album Today's Hits", 'Discogs returned the genre(s): Europop']
# ~~Now recording... https://kexp-mp3-128.streamguys1.com/kexp128.mp3
# Returned:['KEXP2021_11_03_T10_47_40.mp3 ~ song : Goodbye by The Sundays from album Blind', 'Discogs returned the genre(s): Indie Rock']
# ~~Now recording... https://15373.live.streamtheworld.com/KZZUFMAAC_SC
# No ACR return from KZZU2021_11_03_T10_48_15.mp3
# ~~Now recording... https://crystalout.surfernetwork.com:8001/KZQM-FM_MP3
# No ACR return from KZQM2021_11_03_T10_48_53.mp3
# ~~Now recording... http://peridot.streamguys.com:7170/kugs-mp3
# No ACR return from KUGS2021_11_03_T10_48_54.mp3
# ~~Now recording... https://kptz.streamguys1.com/live-mp3
# No ACR return from KPTZ2021_11_03_T10_49_39.mp3
# ~~Now recording... http://192.81.134.38:8001/kbfg-2
# No ACR return from KBFG2021_11_03_T10_50_22.mp3
# ~~Now recording... https://13693.live.streamtheworld.com/KXLYFMAAC.aac
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://stream.pacificaservice.org:9000/kodx
# No ACR return from KODX2021_11_03_T10_51_01.mp3
# ~~Now recording... https://ic1.mainstreamnetwork.com/kghp-fm
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://classicalking.streamguys1.com/king-fm-aac-128k
# No ACR return from KING2021_11_03_T10_51_41.mp3
# ~~Now recording... http://stream1.noctel.com:7003/969kayo
# No ACR return from KYYO2021_11_03_T10_52_24.mp3
# ~~Now recording... https://ice5.securenetsystems.net/KEGX
# No Discogs return from KEGX2021_11_03_T10_53_02.mp3
# ~~Now recording... https://crista-kcms.streamguys1.com/kcmsmp3
# Returned:['KCMS2021_11_03_T10_53_34.mp3 ~ song : Believe For It by CeCe Winans from album Believe For It [Live]', 'Discogs returned the genre(s): Gospel,Vocal']

# %%
for tup in wash_url_cs_tuples:
    it_staysh = Station(WA_FM_CSV, tup[1])
    it_staysh.RollRadio(it_staysh.url, it_staysh.callsign)
# Out:
# ~~Now recording... https://18733.live.streamtheworld.com/KPBX_FM.mp3
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://centova.rockhost.com:8001/stream
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://ic2.sslstream.com/kacs-fm
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://www.ophanim.net:8444/s/7170
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://ice7.securenetsystems.net/KXDD
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://199.180.75.2:9395/stream/;
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://199.180.75.2:9391/;
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://134.121.234.129:8000/NWPRCLASSICAL
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://www.streamcontrol.net:11060/;
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://ophanim.net:7040/;
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://stream.ktqa.org/ktqa.mp3
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://www.ophanim.net:7720/stream
# No ACR return from KBCS2021_11_03_T11_09_49.mp3
# ~~Now recording... http://bustosradio.com:8039/kztm
# No ACR return from KZTM2021_11_03_T11_10_05.mp3
# ~~Now recording... https://17963.live.streamtheworld.com/KEZEFMAAC.aac
# No ACR return from KEZE2021_11_03_T11_10_47.mp3
# ~~Now recording... https://ice10.securenetsystems.net/PLR
# Returned:['KPLW2021_11_03_T11_11_25.mp3 ~ song : The Lion and The Lamb by Big Daddy Weave from album Beautiful Offerings', 'Discogs returned the genre(s): ']
# ~~Now recording... https://ice10.securenetsystems.net/KROH
# No ACR return from KROH2021_11_03_T11_12_01.mp3
# ~~Now recording... http://173.193.205.96:7341/stream
# No Discogs return from KGHI2021_11_03_T11_12_41.mp3
# ~~Now recording... https://streamingv2.shoutcast.com/kupsfm
# No ACR return from KUPS2021_11_03_T11_13_09.mp3
# ~~Now recording... https://usa17.fastcast4u.com/proxy/kievradio?mp=/1
# Returned:['KIEV2021_11_03_T11_13_55.mp3 ~ song : Family Tradition by Hank Williams, Jr. from album Best Of - All My Rowdy Friends', 'Discogs returned the genre(s): Country']
# ~~Now recording... https://video1.getstreamhosting.com:8182/stream
# Returned:['KSQM2021_11_03_T11_14_35.mp3 ~ song : Best Friends (Album Version) by Basia from album London, Warsaw, New York', 'Discogs returned the genre(s): Synth-pop,Contemporary Jazz']
# ~~Now recording... http://205.134.192.90:8930/;
# No ACR return from KAOS2021_11_03_T11_15_20.mp3
# ~~Now recording... https://www.streamvortex.com:8444/s/11390
# Returned:['KMIH2021_11_03_T11_15_50.mp3 ~ song : deja vu by Olivia Rodrigo from album deja vu', 'Discogs returned the genre(s): Power Pop,Pop Punk,Acoustic,Ballad']
# ~~Now recording... https://24883.live.streamtheworld.com/KPBZ_FM.mp3
# No ACR return from KPBZ2021_11_03_T11_16_21.mp3
# ~~Now recording... https://stream.radiotacoma.org/ktah.mp3
# No ACR return from KTAH2021_11_03_T11_16_58.mp3
# ~~Now recording... https://www.streamvortex.com:8444/s/11160
# No ACR return from KEFA2021_11_03_T11_17_37.mp3
# ~~Now recording... http://jade.streamguys1.com:4050/live
# No ACR return from KSER2021_11_03_T11_18_07.mp3
# ~~Now recording... https://live.wostreaming.net/direct/ppm-knkxfmaac256-ibc1
# Returned:['KNKX2021_11_03_T11_18_46.mp3 ~ song : Mile High by Yellowjackets from album Jackets XL', 'Discogs returned the genre(s): ']
# ~~Now recording... https://15363.live.streamtheworld.com/KUOWFM_HIGH_MP3.mp3
# No ACR return from KUOW2021_11_03_T11_19_22.mp3
# ~~Now recording... https://playerservices.streamtheworld.com/api/livestream-redirect/KIROFM.mp3
# No ACR return from KIRO2021_11_03_T11_20_00.mp3
# ~~Now recording... http://204.141.167.19:7090/stream?1573141452215.mp3
# Returned:["KGRG2021_11_03_T11_20_38.mp3 ~ song : Not the Way It Was by Can't Swim from album This Too Won't Pass", 'Discogs returned the genre(s): Emo,Pop Punk,Post-Hardcore']
# ~~Now recording... https://kewuradio.ewu.edu/KEWU_Jazz_89.5
# Returned:["KEWU2021_11_03_T11_21_08.mp3 ~ song : Wading Through by Terence Blanchard from album A Tale Of God's Will (A Requiem For Katrina)", 'Discogs returned the genre(s): ']
# ~~Now recording... http://bustosradio.com:8031/kdds
# No ACR return from KDDS2021_11_03_T11_21_54.mp3
# ~~Now recording... http://shoutcast.whitman.edu:8000/;
# Returned:["KWCW2021_11_03_T11_22_36.mp3 ~ song : Novim's Nightmare by Yusuf / Cat Stevens from album Numbers", 'Discogs returned the genre(s): ']
# ~~Now recording... http://knhc-ice.streamguys1.com/live
# Returned:['KNHC2021_11_03_T11_23_02.mp3 ~ song : I Wanna Be There by DubVision, ANML KNGDM from album I Wanna Be There', 'Discogs returned the genre(s): Progressive House']
# ~~Now recording... https://kexp-mp3-128.streamguys1.com/kexp128.mp3
# Returned:['KEXP2021_11_03_T11_23_07.mp3 ~ song : Unbelievable by EMF from album Le 100 Sexy Hit', 'Discogs returned the genre(s): Alternative Rock,Ballad,Brit Pop,Hip Hop,House,Pop Rap,Pop Rock,RnB/Swing,Synth-pop,UK Garage']
# ~~Now recording... https://15373.live.streamtheworld.com/KZZUFMAAC_SC
# No ACR return from KZZU2021_11_03_T11_23_42.mp3
# ~~Now recording... https://crystalout.surfernetwork.com:8001/KZQM-FM_MP3
# Returned:["KZQM2021_11_03_T11_24_20.mp3 ~ song : Can't Take My Eyes Off You by Frankie Valli from album The Very Best Of Frankie Valli & The 4 Seasons", 'Discogs returned the genre(s): ']
# ~~Now recording... http://peridot.streamguys.com:7170/kugs-mp3
# Returned:['KUGS2021_11_03_T11_24_21.mp3 ~ song : Atomic Bomb by William Onyeabor from album World Psychedelic Classics 5: Who Is William Onyeabor?', 'Discogs returned the genre(s): African,Leftfield,Disco,Psychedelic Rock']
# ~~Now recording... https://kptz.streamguys1.com/live-mp3
# Returned:['KPTZ2021_11_03_T11_25_03.mp3 ~ song : Terra Esperança by Sivuca from album Terra Esperança', 'Discogs returned the genre(s): ']
# ~~Now recording... http://192.81.134.38:8001/kbfg-2
# Returned:['KBFG2021_11_03_T11_25_47.mp3 ~ song : Mexico Esperanza by Dick Dale from album Spacial Disorientation', 'Discogs returned the genre(s): Surf']
# ~~Now recording... https://13693.live.streamtheworld.com/KXLYFMAAC.aac
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://stream.pacificaservice.org:9000/kodx
# No ACR return from KODX2021_11_03_T11_26_26.mp3
# ~~Now recording... https://ic1.mainstreamnetwork.com/kghp-fm
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://classicalking.streamguys1.com/king-fm-aac-128k
# No Discogs return from KING2021_11_03_T11_27_06.mp3
# ~~Now recording... http://stream1.noctel.com:7003/969kayo
# Returned:['KYYO2021_11_03_T11_27_49.mp3 ~ song : Sleepwalk by The Shadows from album You Must Be Hank Marvin (Remastered)', 'Discogs returned the genre(s): ']
# ~~Now recording... https://ice5.securenetsystems.net/KEGX
# No ACR return from KEGX2021_11_03_T11_28_29.mp3
# ~~Now recording... https://crista-kcms.streamguys1.com/kcmsmp3
# No Discogs return from KCMS2021_11_03_T11_29_03.mp3

# %%
for tup in wash_url_cs_tuples:
    it_staysh = Station(WA_FM_CSV, tup[1])
    it_staysh.RollRadio(it_staysh.url, it_staysh.callsign)
# Out:
# ~~Now recording... https://18733.live.streamtheworld.com/KPBX_FM.mp3
# No Discogs return from KPBX2021_11_03_T11_30_03.mp3
# ~~Now recording... http://centova.rockhost.com:8001/stream
# Returned:['KHUH2021_11_03_T11_30_39.mp3 ~ song : Kaplumbağaların Uykusuna Dek by Murat Kemaloğlu from album Kaplumbağaların Uykusuna Dek', 'Discogs returned the genre(s): ']
# ~~Now recording... https://ic2.sslstream.com/kacs-fm
# No Discogs return from KACS2021_11_03_T11_31_22.mp3
# ~~Now recording... https://www.ophanim.net:8444/s/7170
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://ice7.securenetsystems.net/KXDD
# No ACR return from KXDD2021_11_03_T11_31_54.mp3
# ~~Now recording... http://199.180.75.2:9395/stream/;
# No ACR return from KZAX2021_11_03_T11_32_25.mp3
# ~~Now recording... http://199.180.75.2:9391/;
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... http://134.121.234.129:8000/NWPRCLASSICAL
# No Discogs return from KFAE2021_11_03_T11_34_22.mp3
# ~~Now recording... http://www.streamcontrol.net:11060/;
# Returned:['KUKN2021_11_03_T11_35_05.mp3 ~ song : Forever After All by Luke Combs from album Forever After All', 'Discogs returned the genre(s): Country']
# ~~Now recording... http://ophanim.net:7040/;
# Returned:['KOSW2021_11_03_T11_35_36.mp3 ~ song : Life Is A Carnival by The Band from album To Kingdom Come (The Definitive Collection)', 'Discogs returned the genre(s): Folk Rock,Country Rock,Blues Rock,Classic Rock']
# ~~Now recording... https://stream.ktqa.org/ktqa.mp3
# No ACR return from KTQA2021_11_03_T11_36_06.mp3
# ~~Now recording... http://www.ophanim.net:7720/stream
# No ACR return from KBCS2021_11_03_T11_36_42.mp3
# ~~Now recording... http://bustosradio.com:8039/kztm
# No ACR return from KZTM2021_11_03_T11_36_58.mp3
# ~~Now recording... https://17963.live.streamtheworld.com/KEZEFMAAC.aac
# Returned:['KEZE2021_11_03_T11_38_27.mp3 ~ song : Have Mercy by Chlöe from album Have Mercy', 'Discogs returned the genre(s): Indie Rock,Art Rock']
# ~~Now recording... https://ice10.securenetsystems.net/PLR
# Returned:['KPLW2021_11_03_T11_39_05.mp3 ~ song : Whom Shall I Fear [God of Angel Armies] by Chris Tomlin from album Burning Lights', 'Discogs returned the genre(s): ']
# ~~Now recording... https://ice10.securenetsystems.net/KROH
# No ACR return from KROH2021_11_03_T11_39_42.mp3
# ~~Now recording... http://173.193.205.96:7341/stream
# No Discogs return from KGHI2021_11_03_T11_40_21.mp3
# ~~Now recording... https://streamingv2.shoutcast.com/kupsfm
# No ACR return from KUPS2021_11_03_T11_40_49.mp3
# ~~Now recording... https://usa17.fastcast4u.com/proxy/kievradio?mp=/1
# Returned:['KIEV2021_11_03_T11_41_31.mp3 ~ song : The Thunder Rolls by Garth Brooks from album The Ultimate Hits', 'Discogs returned the genre(s): ']
# ~~Now recording... https://video1.getstreamhosting.com:8182/stream
# Returned:["KSQM2021_11_03_T11_42_12.mp3 ~ song : Rebeca's Waltz by Marc Antoine from album Madrid", 'Discogs returned the genre(s): Smooth Jazz']
# ~~Now recording... http://205.134.192.90:8930/;
# No ACR return from KAOS2021_11_03_T11_42_53.mp3
# ~~Now recording... https://www.streamvortex.com:8444/s/11390
# No ACR return from KMIH2021_11_03_T11_43_23.mp3
# ~~Now recording... https://24883.live.streamtheworld.com/KPBZ_FM.mp3
# No ACR return from KPBZ2021_11_03_T11_43_53.mp3
# ~~Now recording... https://stream.radiotacoma.org/ktah.mp3
# No ACR return from KTAH2021_11_03_T11_44_31.mp3
# ~~Now recording... https://www.streamvortex.com:8444/s/11160
# No ACR return from KEFA2021_11_03_T11_45_09.mp3
# ~~Now recording... http://jade.streamguys1.com:4050/live
# No Discogs return from KSER2021_11_03_T11_45_40.mp3
# ~~Now recording... https://live.wostreaming.net/direct/ppm-knkxfmaac256-ibc1
# Returned:['KNKX2021_11_03_T11_46_18.mp3 ~ song : The Rhythm Section by Dan Wilson from album Vessels of Wood and Earth', 'Discogs returned the genre(s): ']
# ~~Now recording... https://15363.live.streamtheworld.com/KUOWFM_HIGH_MP3.mp3
# No ACR return from KUOW2021_11_03_T11_46_52.mp3
# ~~Now recording... https://playerservices.streamtheworld.com/api/livestream-redirect/KIROFM.mp3
# No ACR return from KIRO2021_11_03_T11_49_08.mp3
# ~~Now recording... http://204.141.167.19:7090/stream?1573141452215.mp3
# Returned:["KGRG2021_11_03_T11_49_53.mp3 ~ song : I'm Already Gone by A Day To Remember from album Common Courtesy", 'Discogs returned the genre(s): Pop Punk,Metalcore']
# ~~Now recording... https://kewuradio.ewu.edu/KEWU_Jazz_89.5
# No Discogs return from KEWU2021_11_03_T11_50_24.mp3
# ~~Now recording... http://bustosradio.com:8031/kdds
# No ACR return from KDDS2021_11_03_T11_51_09.mp3
# ~~Now recording... http://shoutcast.whitman.edu:8000/;
# Returned:['KWCW2021_11_03_T11_51_51.mp3 ~ song : Something About Us by Daft Punk from album something about us (love theme from interstella)', 'Discogs returned the genre(s): House,Broken Beat,Deep House']
# ~~Now recording... http://knhc-ice.streamguys1.com/live
# Returned:['KNHC2021_11_03_T11_52_17.mp3 ~ song : High Hopes (Don Diablo Remix) by Panic! At The Disco from album High Hopes (Don Diablo Remix)', 'Discogs returned the genre(s): Electro']
# ~~Now recording... https://kexp-mp3-128.streamguys1.com/kexp128.mp3
# Returned:['KEXP2021_11_03_T11_52_22.mp3 ~ song : The Rat by The Walkmen from album Bows + Arrows', 'Discogs returned the genre(s): Indie Rock']
# ~~Now recording... https://15373.live.streamtheworld.com/KZZUFMAAC_SC
# No ACR return from KZZU2021_11_03_T11_52_57.mp3
# ~~Now recording... https://crystalout.surfernetwork.com:8001/KZQM-FM_MP3
# Returned:['KZQM2021_11_03_T11_53_42.mp3 ~ song : You Wear it Well by Rod Stewart from album The Story So Far-Very Best of', 'Discogs returned the genre(s): Pop Rock,Soft Rock,Ballad']
# ~~Now recording... http://peridot.streamguys.com:7170/kugs-mp3
# Returned:['KUGS2021_11_03_T11_53_43.mp3 ~ song : Upside Down by Fela Kuti from album Upside Down / Music Of Many Colours', 'Discogs returned the genre(s): Afrobeat,Jazz-Funk']
# ~~Now recording... https://kptz.streamguys1.com/live-mp3
# No ACR return from KPTZ2021_11_03_T11_54_26.mp3
# ~~Now recording... http://192.81.134.38:8001/kbfg-2
# Returned:['KBFG2021_11_03_T11_55_08.mp3 ~ song : La Pistola Y El Corazón by Los Lobos from album La Pistola Y El Corazon', 'Discogs returned the genre(s): Norteño,Son,Ranchera,Mariachi']
# ~~Now recording... https://13693.live.streamtheworld.com/KXLYFMAAC.aac
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://stream.pacificaservice.org:9000/kodx
# No ACR return from KODX2021_11_03_T11_55_48.mp3
# ~~Now recording... https://ic1.mainstreamnetwork.com/kghp-fm
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://classicalking.streamguys1.com/king-fm-aac-128k
# Returned:['KING2021_11_03_T11_56_28.mp3 ~ song : Scott Joplin: The Entertainer by Erich Kunzel from album American Piano Classics', 'Discogs returned the genre(s): ']
# ~~Now recording... http://stream1.noctel.com:7003/969kayo
# Returned:["KYYO2021_11_03_T11_57_12.mp3 ~ song : What’s Your Country Song by Thomas Rhett from album What's Your Country Song", 'Discogs returned the genre(s): ']
# ~~Now recording... https://ice5.securenetsystems.net/KEGX
# No Discogs return from KEGX2021_11_03_T11_57_52.mp3
# ~~Now recording... https://crista-kcms.streamguys1.com/kcmsmp3
# No Discogs return from KCMS2021_11_03_T11_58_23.mp3

# %%
for tup in wash_url_cs_tuples:
    it_staysh = Station(WA_FM_CSV, tup[1])
    it_staysh.RollRadio(it_staysh.url, it_staysh.callsign)
# Out:
# ~~Now recording... https://18733.live.streamtheworld.com/KPBX_FM.mp3
# No ACR return from KPBX2021_11_03_T14_31_51.mp3
# ~~Now recording... http://centova.rockhost.com:8001/stream
# No ACR return from KHUH2021_11_03_T14_32_28.mp3
# ~~Now recording... https://ic2.sslstream.com/kacs-fm
# Returned:['KACS2021_11_03_T14_33_11.mp3 ~ song : Christ In You [Instrumental] by Integrity Music from album Experience Hope [Instrumental]', 'Discogs returned the genre(s): Religious']
# ~~Now recording... https://www.ophanim.net:8444/s/7170
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://ice7.securenetsystems.net/KXDD
# No ACR return from KXDD2021_11_03_T14_33_42.mp3
# ~~Now recording... http://199.180.75.2:9395/stream/;
# Returned:['KZAX2021_11_03_T14_34_15.mp3 ~ song : 5 Million Ways To Kill A C.E.O. by The Coup from album Party Music', 'Discogs returned the genre(s): Conscious,Funk']
# ~~Now recording... http://199.180.75.2:9391/;
# Returned:["KMRE2021_11_03_T14_34_43.mp3 ~ song : I'm On Your Side by Bonnie Raitt from album Fundamental", 'Discogs returned the genre(s): Blues Rock,Pop Rock']
# ~~Now recording... http://134.121.234.129:8000/NWPRCLASSICAL
# Returned:['KFAE2021_11_03_T14_35_14.mp3 ~ song : Rhapsody in Blue by Lincoln Mayorga from album A Gershwin Celebration', 'Discogs returned the genre(s): ']
# ~~Now recording... http://www.streamcontrol.net:11060/;
# Returned:["KUKN2021_11_03_T14_35_58.mp3 ~ song : We Didn't Have Much by Justin Moore from album We Didn't Have Much", 'Discogs returned the genre(s): Country,Western Swing,Honky Tonk']
# ~~Now recording... http://ophanim.net:7040/;
# No ACR return from KOSW2021_11_03_T14_36_28.mp3
# ~~Now recording... https://stream.ktqa.org/ktqa.mp3
# No ACR return from KTQA2021_11_03_T14_36_59.mp3
# ~~Now recording... http://www.ophanim.net:7720/stream
# No Discogs return from KBCS2021_11_03_T14_37_35.mp3
# ~~Now recording... http://bustosradio.com:8039/kztm
# Returned:['KZTM2021_11_03_T14_37_54.mp3 ~ song : Me Quede Llorando by Industria Del Amor from album Verano De Amor', 'Discogs returned the genre(s): ']
# ~~Now recording... https://17963.live.streamtheworld.com/KEZEFMAAC.aac
# Returned:["KEZE2021_11_03_T14_38_37.mp3 ~ song : Pullin' Me Back by Chingy from album Hoodstar", 'Discogs returned the genre(s): ']
# ~~Now recording... https://ice10.securenetsystems.net/PLR
# No ACR return from KPLW2021_11_03_T14_39_15.mp3
# ~~Now recording... https://ice10.securenetsystems.net/KROH
# No ACR return from KROH2021_11_03_T14_39_52.mp3
# ~~Now recording... http://173.193.205.96:7341/stream
# No ACR return from KGHI2021_11_03_T14_40_31.mp3
# ~~Now recording... https://streamingv2.shoutcast.com/kupsfm
# Returned:['KUPS2021_11_03_T14_41_02.mp3 ~ song : Breathe In, Breathe Out by Set It Off from album Horrible Kids', 'Discogs returned the genre(s): Alternative Rock']
# ~~Now recording... https://usa17.fastcast4u.com/proxy/kievradio?mp=/1
# Returned:["KIEV2021_11_03_T14_41_45.mp3 ~ song : Give All You Can by Cody Jinks from album I'm Not The Devil", 'Discogs returned the genre(s): Country']
# ~~Now recording... https://video1.getstreamhosting.com:8182/stream
# No Discogs return from KSQM2021_11_03_T14_42_26.mp3
# ~~Now recording... http://205.134.192.90:8930/;
# Returned:['KAOS2021_11_03_T14_43_08.mp3 ~ song : Something by Chandra from album Transportation', 'Discogs returned the genre(s): No Wave']
# ~~Now recording... https://www.streamvortex.com:8444/s/11390
# Returned:['KMIH2021_11_03_T14_43_38.mp3 ~ song : Hang Loose by Alabama Shakes from album Boys & Girls', 'Discogs returned the genre(s): Southern Rock']
# ~~Now recording... https://24883.live.streamtheworld.com/KPBZ_FM.mp3
# No ACR return from KPBZ2021_11_03_T14_44_12.mp3
# ~~Now recording... https://stream.radiotacoma.org/ktah.mp3
# No ACR return from KTAH2021_11_03_T14_44_49.mp3
# ~~Now recording... https://www.streamvortex.com:8444/s/11160
# No ACR return from KEFA2021_11_03_T14_45_26.mp3
# ~~Now recording... http://jade.streamguys1.com:4050/live
# Returned:['KSER2021_11_03_T14_45_57.mp3 ~ song : Fire by Black Pumas from album Fire / Black Moon Rising', 'Discogs returned the genre(s): Psychedelic,Soul']
# ~~Now recording... https://live.wostreaming.net/direct/ppm-knkxfmaac256-ibc1
# No Discogs return from KNKX2021_11_03_T14_46_37.mp3
# ~~Now recording... https://15363.live.streamtheworld.com/KUOWFM_HIGH_MP3.mp3
# No ACR return from KUOW2021_11_03_T14_47_14.mp3
# ~~Now recording... https://playerservices.streamtheworld.com/api/livestream-redirect/KIROFM.mp3
# No ACR return from KIRO2021_11_03_T14_47_53.mp3
# ~~Now recording... http://204.141.167.19:7090/stream?1573141452215.mp3
# No ACR return from KGRG2021_11_03_T14_48_38.mp3
# ~~Now recording... https://kewuradio.ewu.edu/KEWU_Jazz_89.5
# Returned:['KEWU2021_11_03_T14_49_08.mp3 ~ song : The Scene Is Clean by Clifford Brown from album Clifford Brown And Max Roach At Basin Street', 'Discogs returned the genre(s): Bop,Hard Bop']
# ~~Now recording... http://bustosradio.com:8031/kdds
# No Discogs return from KDDS2021_11_03_T14_49_54.mp3
# ~~Now recording... http://shoutcast.whitman.edu:8000/;
# Returned:['KWCW2021_11_03_T14_50_36.mp3 ~ song : Wonderful by Joel Grey from album 101 Broadway Musicals', 'Discogs returned the genre(s): Musical']
# ~~Now recording... http://knhc-ice.streamguys1.com/live
# Returned:['KNHC2021_11_03_T14_51_02.mp3 ~ song : Teenage Dream by Katy Perry from album Teenage Dream - Remix EP', 'Discogs returned the genre(s): ']
# ~~Now recording... https://kexp-mp3-128.streamguys1.com/kexp128.mp3
# Returned:['KEXP2021_11_03_T14_51_08.mp3 ~ song : You Dropped A Bomb On Me by The Gap Band from album Gap Gold - Best Of The Gap Band', 'Discogs returned the genre(s): Funk']
# ~~Now recording... https://15373.live.streamtheworld.com/KZZUFMAAC_SC
# Returned:['KZZU2021_11_03_T14_51_43.mp3 ~ song : Señorita by Shawn Mendes from album Señorita', 'Discogs returned the genre(s): ']
# ~~Now recording... https://crystalout.surfernetwork.com:8001/KZQM-FM_MP3
# Returned:['KZQM2021_11_03_T14_52_21.mp3 ~ song : More, More, More, Pt. 1 by Andrea True Connection from album More Monty', 'Discogs returned the genre(s): Synth-pop,Disco']
# ~~Now recording... http://peridot.streamguys.com:7170/kugs-mp3
# Returned:['KUGS2021_11_03_T14_52_23.mp3 ~ song : Telefone by Bossacucanova &  Roberto Menescal from album Telefone', 'Discogs returned the genre(s): Bossanova']
# ~~Now recording... https://kptz.streamguys1.com/live-mp3
# No ACR return from KPTZ2021_11_03_T14_53_07.mp3
# ~~Now recording... http://192.81.134.38:8001/kbfg-2
# No ACR return from KBFG2021_11_03_T14_53_50.mp3
# ~~Now recording... https://13693.live.streamtheworld.com/KXLYFMAAC.aac
# Returned:['KXLY2021_11_03_T14_54_29.mp3 ~ song : Come Back As A Country Boy by Blake Shelton from album Come Back As A Country Boy', 'Discogs returned the genre(s): ']
# ~~Now recording... https://stream.pacificaservice.org:9000/kodx
# No ACR return from KODX2021_11_03_T14_55_06.mp3
# ~~Now recording... https://ic1.mainstreamnetwork.com/kghp-fm
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://classicalking.streamguys1.com/king-fm-aac-128k
# No Discogs return from KING2021_11_03_T14_55_46.mp3
# ~~Now recording... http://stream1.noctel.com:7003/969kayo
# No ACR return from KYYO2021_11_03_T14_56_30.mp3
# ~~Now recording... https://ice5.securenetsystems.net/KEGX
# Returned:["KEGX2021_11_03_T14_57_09.mp3 ~ song : You've Got Another Thing Comin' by Judas Priest from album British Steel/Point Of Entry/Screaming For Vengeance (3 Pak)", 'Discogs returned the genre(s): Hard Rock,Heavy Metal']
# ~~Now recording... https://crista-kcms.streamguys1.com/kcmsmp3
# Returned:['KCMS2021_11_03_T14_57_40.mp3 ~ song : The Thanksgiving Song by Ben Rector from album The Thanksgiving Song', 'Discogs returned the genre(s): ']

# %%
for tup in wash_url_cs_tuples:
    it_staysh = Station(WA_FM_CSV, tup[1])
    it_staysh.RollRadio(it_staysh.url, it_staysh.callsign)
# Out:
# ~~Now recording... https://18733.live.streamtheworld.com/KPBX_FM.mp3
# Returned:['KPBX2021_11_03_T15_32_34.mp3 ~ song : Let It Be (Remaster) by The Beatles from album Let It Be (Remastered)', 'Discogs returned the genre(s): Pop Rock']
# ~~Now recording... http://centova.rockhost.com:8001/stream
# Returned:['KHUH2021_11_03_T15_33_11.mp3 ~ song : Marzipan by Cluster from album Zuckerzeit', 'Discogs returned the genre(s): Downtempo,Experimental']
# ~~Now recording... https://ic2.sslstream.com/kacs-fm
# Returned:['KACS2021_11_03_T15_33_54.mp3 ~ song : My Jesus by Anne Wilson from album My Jesus', 'Discogs returned the genre(s): Gospel']
# ~~Now recording... https://www.ophanim.net:8444/s/7170
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://ice7.securenetsystems.net/KXDD
# No ACR return from KXDD2021_11_03_T15_34_26.mp3
# ~~Now recording... http://199.180.75.2:9395/stream/;
# Returned:['KZAX2021_11_03_T15_34_59.mp3 ~ song : Kamane Tarhanin by Mdou Moctar from album Kamane Tarhanin', 'Discogs returned the genre(s): African,Folk Rock']
# ~~Now recording... http://199.180.75.2:9391/;
# Returned:['KMRE2021_11_03_T15_35_28.mp3 ~ song : Bank Robber by Eli Paperboy Reed from album Bank Robber', 'Discogs returned the genre(s): Soul']
# ~~Now recording... http://134.121.234.129:8000/NWPRCLASSICAL
# No ACR return from KFAE2021_11_03_T15_35_59.mp3
# ~~Now recording... http://www.streamcontrol.net:11060/;
# Returned:['KUKN2021_11_03_T15_36_42.mp3 ~ song : American Kids by Kenny Chesney from album The Big Revival', 'Discogs returned the genre(s): Country']
# ~~Now recording... http://ophanim.net:7040/;
# No Discogs return from KOSW2021_11_03_T15_37_12.mp3
# ~~Now recording... https://stream.ktqa.org/ktqa.mp3
# No ACR return from KTQA2021_11_03_T15_37_43.mp3
# ~~Now recording... http://www.ophanim.net:7720/stream
# No ACR return from KBCS2021_11_03_T15_38_20.mp3
# ~~Now recording... http://bustosradio.com:8039/kztm
# No Discogs return from KZTM2021_11_03_T15_38_35.mp3
# ~~Now recording... https://17963.live.streamtheworld.com/KEZEFMAAC.aac
# No ACR return from KEZE2021_11_03_T15_39_18.mp3
# ~~Now recording... https://ice10.securenetsystems.net/PLR
# Returned:['KPLW2021_11_03_T15_40_01.mp3 ~ song : Next To Me by Jordan Feliz from album Next To Me', 'Discogs returned the genre(s): ']
# ~~Now recording... https://ice10.securenetsystems.net/KROH
# No ACR return from KROH2021_11_03_T15_40_38.mp3
# ~~Now recording... http://173.193.205.96:7341/stream
# No Discogs return from KGHI2021_11_03_T15_41_17.mp3
# ~~Now recording... https://streamingv2.shoutcast.com/kupsfm
# Returned:['KUPS2021_11_03_T15_41_46.mp3 ~ song : How Lucky by John Prine;Kurt Vile from album How Lucky', 'Discogs returned the genre(s): ']
# ~~Now recording... https://usa17.fastcast4u.com/proxy/kievradio?mp=/1
# Returned:["KIEV2021_11_03_T15_42_29.mp3 ~ song : The Way I Am by George Jones from album Kickin' Out The Footlights... Again: Jones Sings Haggard, Haggard Sings Jones", 'Discogs returned the genre(s): Country']
# ~~Now recording... https://video1.getstreamhosting.com:8182/stream
# Returned:['KSQM2021_11_03_T15_43_09.mp3 ~ song : Play Something Sweet (Brickyard Blues) by Three Dog Night from album The Collection', 'Discogs returned the genre(s): Classic Rock']
# ~~Now recording... http://205.134.192.90:8930/;
# No Discogs return from KAOS2021_11_03_T15_43_51.mp3
# ~~Now recording... https://www.streamvortex.com:8444/s/11390
# Returned:['KMIH2021_11_03_T15_44_22.mp3 ~ song : Levitating by Dua Lipa from album Levitating', 'Discogs returned the genre(s): House,Dance-pop']
# ~~Now recording... https://24883.live.streamtheworld.com/KPBZ_FM.mp3
# No ACR return from KPBZ2021_11_03_T15_44_53.mp3
# ~~Now recording... https://stream.radiotacoma.org/ktah.mp3
# No ACR return from KTAH2021_11_03_T15_45_33.mp3
# ~~Now recording... https://www.streamvortex.com:8444/s/11160
# No ACR return from KEFA2021_11_03_T15_46_10.mp3
# ~~Now recording... http://jade.streamguys1.com:4050/live
# No Discogs return from KSER2021_11_03_T15_46_40.mp3
# ~~Now recording... https://live.wostreaming.net/direct/ppm-knkxfmaac256-ibc1
# Returned:['KNKX2021_11_03_T15_47_18.mp3 ~ song : Madrid by Brad Mehldau from album Madrid', 'Discogs returned the genre(s): Contemporary Jazz']
# ~~Now recording... https://15363.live.streamtheworld.com/KUOWFM_HIGH_MP3.mp3
# No ACR return from KUOW2021_11_03_T15_47_52.mp3
# ~~Now recording... https://playerservices.streamtheworld.com/api/livestream-redirect/KIROFM.mp3
# No ACR return from KIRO2021_11_03_T15_48_30.mp3
# ~~Now recording... http://204.141.167.19:7090/stream?1573141452215.mp3
# Returned:['KGRG2021_11_03_T15_49_12.mp3 ~ song : Sing Me to Sleep by Avion Roe from album In Separation', 'Discogs returned the genre(s): ']
# ~~Now recording... https://kewuradio.ewu.edu/KEWU_Jazz_89.5
# Returned:['KEWU2021_11_03_T15_49_43.mp3 ~ song : In The Meantime by Joe Martin from album Not By Chance', 'Discogs returned the genre(s): Contemporary Jazz']
# ~~Now recording... http://bustosradio.com:8031/kdds
# Returned:['KDDS2021_11_03_T15_50_28.mp3 ~ song : Cómo Te Olvido by La Arrolladora Banda El Limón De René Camacho from album Cómo Te Olvido', 'Discogs returned the genre(s): Norteño,Corrido,Cumbia,Tejano']
# ~~Now recording... http://shoutcast.whitman.edu:8000/;
# Returned:['KWCW2021_11_03_T15_51_10.mp3 ~ song : Deja Vu (2006 Remaster) by Crosby, Stills, Nash & Young from album Deja Vu (2006 Remaster)', 'Discogs returned the genre(s): Folk Rock,Pop Rock,Classic Rock,Soft Rock,Country Rock']
# ~~Now recording... http://knhc-ice.streamguys1.com/live
# No Discogs return from KNHC2021_11_03_T15_51_36.mp3
# ~~Now recording... https://kexp-mp3-128.streamguys1.com/kexp128.mp3
# No Discogs return from KEXP2021_11_03_T15_51_42.mp3
# ~~Now recording... https://15373.live.streamtheworld.com/KZZUFMAAC_SC
# Returned:['KZZU2021_11_03_T15_52_17.mp3 ~ song : Angel Baby by Troye Sivan from album Angel Baby', 'Discogs returned the genre(s): House,Dance-pop,Vocal,Electro House,Grime,Country,Soundtrack,Indie Pop']
# ~~Now recording... https://crystalout.surfernetwork.com:8001/KZQM-FM_MP3
# Returned:['KZQM2021_11_03_T15_52_54.mp3 ~ song : I Saw The Light by Todd Rundgren from album Definitive Rock: Todd Rundgren', 'Discogs returned the genre(s): Classic Rock']
# ~~Now recording... http://peridot.streamguys.com:7170/kugs-mp3
# Returned:['KUGS2021_11_03_T15_52_56.mp3 ~ song : Anyhow by Tedeschi Trucks Band from album Anyhow', 'Discogs returned the genre(s): Blues Rock']
# ~~Now recording... https://kptz.streamguys1.com/live-mp3
# No ACR return from KPTZ2021_11_03_T15_53_39.mp3
# ~~Now recording... http://192.81.134.38:8001/kbfg-2
# No Discogs return from KBFG2021_11_03_T15_54_22.mp3
# ~~Now recording... https://13693.live.streamtheworld.com/KXLYFMAAC.aac
# Returned:["KXLY2021_11_03_T15_55_01.mp3 ~ song : You Ain't Pretty by Nate Barnes from album You Ain't Pretty", 'Discogs returned the genre(s): Ballad,Vocal,Swing']
# ~~Now recording... https://stream.pacificaservice.org:9000/kodx
# No ACR return from KODX2021_11_03_T15_55_39.mp3
# ~~Now recording... https://ic1.mainstreamnetwork.com/kghp-fm
# Error - Sampler could not work on URL stream. Skipping station.
# ~~Now recording... https://classicalking.streamguys1.com/king-fm-aac-128k
# No Discogs return from KING2021_11_03_T15_56_20.mp3
# ~~Now recording... http://stream1.noctel.com:7003/969kayo
# No ACR return from KYYO2021_11_03_T15_57_05.mp3
# ~~Now recording... https://ice5.securenetsystems.net/KEGX
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-08ebeca49c81> in <module>
#       1 for tup in wash_url_cs_tuples:
#       2     it_staysh = Station(WA_FM_CSV, tup[1])
# ----> 3     it_staysh.RollRadio(it_staysh.url, it_staysh.callsign)
#
# <ipython-input-13-ec4eb8dc1217> in RollRadio(self, url, callsign)
#     120                     discogs_songinfo_dict = json.loads(discogs_req_obj.content.decode('utf-8'))
#     121
# --> 122                     if discogs_songinfo_dict['results'] == []:
#     123                         print(f'No Discogs return from {input_mp3name}')
#     124                         pass
#
# KeyError: 'results'

# %%
with open(KEXP.txtpath, "r") as file_object:
    Lines = file_object.readlines()
    cleanLines = []
    txtheader = [0,1,2]
    for i in range(len(Lines)):
        if i not in txtheader:
            cleanLines.append(Lines[i])
    
for line in cleanLines:
    print(line)
# Out:
# KEXP2021_10_25_T19_59_19.mp3,song=Friends,artist=Big Gigantic,album=Free Your Mind,styles=Hip Hop
#
# KEXP2021_10_26_T11_12_56.mp3,song=holy calamafuck,artist=Run The Jewels,album=holy calamafuck,styles=
#
# KEXP2021_10_26_T12_19_42.mp3,song=The Joke,artist=Brandi Carlile,album=The Joke,styles=Pop Rock,Rock & Roll,Country Rock,Country
#
# KEXP2021_10_26_T12_50_29.mp3,song=The Beachland Ballroom,artist=IDLES,album=The Beachland Ballroom,styles=
#
# KEXP2021_10_27_T10_19_23.mp3,song=Velouria,artist=Pixies,album=Bossanova,styles=Indie Rock
#
# KEXP2021_10_27_T10_37_45.mp3,song=Clean Air,artist=Hand Habits,album=Fun House,styles=
#
# KEXP2021_10_27_T11_31_40.mp3,song=Sunrise,artist=Explosions In The Sky,album=Big Bend (An Original Soundtrack for Public Television),styles=Post Rock,Soundtrack
#
# KEXP2021_10_27_T12_05_38.mp3,song=Marching Bands of Manhattan,artist=Death Cab for Cutie,album=Marching Bands of Manhattan,styles=Indie Rock
#
# KEXP2021_10_27_T12_28_13.mp3,song=Nighttime Drive,artist=Jay Som,album=Anak Ko,styles=Indie Rock,Lo-Fi,Indie Pop
#
# KEXP2021_10_27_T12_31_57.mp3,song=Come Around,artist=Breeze,album=Only Up,styles=Post-Punk,Brit Pop,Alternative Rock,Dream Pop
#
# KEXP2021_10_27_T12_38_08.mp3,song=Less Yes's, More No's,artist=Busdriver,album=RoadKill Overcoat,styles=Abstract
#
# KEXP2021_11_03_T10_47_40.mp3,song=Goodbye,artist=The Sundays,album=Blind,styles=Indie Rock
#
# KEXP2021_11_03_T11_23_07.mp3,song=Unbelievable,artist=EMF,album=Le 100 Sexy Hit,styles=Alternative Rock,Ballad,Brit Pop,Hip Hop,House,Pop Rap,Pop Rock,RnB/Swing,Synth-pop,UK Garage
#
# KEXP2021_11_03_T11_52_22.mp3,song=The Rat,artist=The Walkmen,album=Bows + Arrows,styles=Indie Rock
#
# KEXP2021_11_03_T14_51_08.mp3,song=You Dropped A Bomb On Me,artist=The Gap Band,album=Gap Gold - Best Of The Gap Band,styles=Funk

# %%
genresplit1 = cleanLines[0].split("styles=")[1]
genrecomma = genresplit1.split('\n')[0]
genrelist = genrecomma.split(',')
genrelist
# Out:
# ['Pop Rock']

# %%
stuffbeforegenre = cleanLines[0].split(",styles")[0]
albumparse = stuffbeforegenre.split('album=')[1]
albumparse
# Out:
# 'Let It Be (Remastered)'

# %%
stuffbeforealbum = stuffbeforegenre.split(",album=")[0]
artistparse = stuffbeforealbum.split(",artist=")[1]
artistparse
# Out:
# 'The Beatles'

# %%
stuffbeforeartist = stuffbeforealbum.split(",artist=")[0]
songparse = stuffbeforeartist.split(",song=")[1]
songparse
# Out:
# 'Let It Be (Remaster)'

# %%
mp3filename = stuffbeforeartist.split(",song=")[0]
mp3filename
# Out:
# 'KPBX2021_11_03_T15_32_34.mp3'

# %%
mp3_components = mp3filename.split('_')
mp3_components[-1] = mp3_components[-1].split('.mp3')[0]
mp3_components
# Out:
# ['KPBX2021', '11', '03', 'T15', '32', '34']

# %%
stateabrev
# Out:
# 'KPBX2021'

# %%
radiocallsgn
# Out:
# 'KPBX2021'

# %%
#radiocallsgn = mp3_components[0]

stateabrev = 'WA'
captureyear = mp3_components[0].split('KPBX')[1] # ENTER IN ITERSTAYSH.CALLSIGN
capturemonth = mp3_components[1]
captureday = mp3_components[2]
capturehour = mp3_components[3].split('T')[1]
captureminute = mp3_components[4]
capturesecond = mp3_components[5]
                                     
print('STATE :',stateabrev)   # THIS IS GONNA NEED TO BE CODED PROPERLY EVENTUALLY
#print('CALLSIGN :',radiocallsgn)  # JUST ACCESS THRU STATION.CALLSIGN
print('SONG NAME :',songparse)
print('ARTIST NAME :',artistparse)
print('ALBUM NAME :',albumparse)
print('STYLES :',genrecomma)
print('YEAR OF CAPTURE :',captureyear)
print('MONTH OF CAPTURE:',capturemonth)
print('DAY OF CAPTURE :',captureday)
print('HOUR OF CAPTURE :',capturehour)
print('MINUTE OF CAPTURE :',captureminute)
print('SECOND OF CAPTURE :',capturesecond)
# Out:
# STATE : WA
# SONG NAME : Let It Be (Remaster)
# ARTIST NAME : The Beatles
# ALBUM NAME : Let It Be (Remastered)
# STYLES : Pop Rock
# YEAR OF CAPTURE : 2021
# MONTH OF CAPTURE: 11
# DAY OF CAPTURE : 03
# HOUR OF CAPTURE : 15
# MINUTE OF CAPTURE : 32
# SECOND OF CAPTURE : 34

# %%
TrackPlayLogDict = {}

for station in wash_callsign_folds:
    
    iterstaysh = Station(WA_FM_CSV, station)
    timerightnow = datetime.now()
    YMD_rightnow = timerightnow.strftime("%Y_%m_%d")
    
    TrackPlayLogDict[station] = {}
    tracklogCSVpath = os.path.join(iterstaysh.foldpath,
                                   f'{station}_TrackLog_{YMD_rightnow}.csv')
    
    with open(iterstaysh.txtpath, "r") as file_object:
        Lines = file_object.readlines()
        cleanLines = []
        txtheader = [0,1,2]
        for i in range(len(Lines)):
            if i not in txtheader:
                cleanLines.append(Lines[i])
        
    with open(tracklogCSVpath,'w',newline='') as csvfile:
        fieldnames = ['stateabrev',
                      'radiocallsgn',
                      'trackname',
                      'trackartist',
                      'trackalbum',
                      'trackstyles',
                      'trackmp3filename',
                      'captureyear',
                      'capturemonth',
                      'captureday',
                      'capturehour',
                      'captureminute',
                      'capturesecond']
        
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        
        for trackplaystring in cleanLines:
            
            genresplit1 = trackplaystring.split("styles=")[1]
            genrecomma = genresplit1.split('\n')[0]
            genrelist = genrecomma.split(',')
            genrecommastr = ",".join(genrelist)
            
            stuffbeforegenre = trackplaystring.split(",styles")[0]
            albumparse = stuffbeforegenre.split('album=')[1]
            
            stuffbeforealbum = stuffbeforegenre.split(",album=")[0]
            artistparse = stuffbeforealbum.split(",artist=")[1]

            stuffbeforeartist = stuffbeforealbum.split(",artist=")[0]
            songparse = stuffbeforeartist.split(",song=")[1]
            
            mp3filename = stuffbeforeartist.split(",song=")[0]
            
            mp3_components = mp3filename.split('_')
            mp3_components[-1] = mp3_components[-1].split('.mp3')[0]
            
            stateabrev = 'WA' # THIS IS GONNA NEED TO BE CODED PROPERLY EVENTUALLY
            radiocallsgn = station
            captureyear = mp3_components[0].split(station)[1]
            capturemonth = mp3_components[1]
            captureday = mp3_components[2]
            capturehour = mp3_components[3].split('T')[1]
            captureminute = mp3_components[4]
            capturesecond = mp3_components[5]
            
            writer.writerow({
                'stateabrev' : stateabrev,
                'radiocallsgn' : radiocallsgn,
                'trackname' : songparse,
                'trackartist' : artistparse,
                'trackalbum' : albumparse,
                'trackstyles' : genrecommastr,
                'trackmp3filename' : mp3filename,
                'captureyear' : captureyear,
                'capturemonth' : capturemonth,
                'captureday' : captureday,
                'capturehour' : capturehour,
                'captureminute' : captureminute,
                'capturesecond' : capturesecond
            })
print("*~*~~~~~**~~~~~~~~~~~~~~**~*~*\n"
      "Sucessfully printed track play log CSVs for all stations."+
      "\nAll CSVs outputted to respective station folders."+
      f"\nThis batch of CSVs have the extension: {YMD_rightnow}.csv"+
      "\n*~*~~~~~**~~~~~~~~~~~~~~**~*~*")
# Out:
# *~*~~~~~**~~~~~~~~~~~~~~**~*~*
# Sucessfully printed track play log CSVs for all stations.
# All CSVs outputted to respective station folders.
# This batch of CSVs have the extension: 2021_11_03.csv
# *~*~~~~~**~~~~~~~~~~~~~~**~*~*

# %%
iterstaysh.foldpath
# Out:
# ('/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS', 'KPBX')

# %%
cleanLines
# Out:
# ['KPBX2021_11_03_T15_32_34.mp3,song=Let It Be (Remaster),artist=The Beatles,album=Let It Be (Remastered),styles=Pop Rock']

# %%
mp3_components
# Out:
# ['KPBX2021', '11', '03', 'T15', '32', '34']

# %%
KEXP_tracklog = r'/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS/KEXP/KEXP_TrackLog_2021_11_03.csv'
KEXP_track_df = pd.read_csv(KEXP_tracklog)
KEXP_track_df
# Out:
#    stateabrev radiocallsgn                    trackname  \
# 0          WA         KEXP                      Friends
# 1          WA         KEXP              holy calamafuck
# 2          WA         KEXP                     The Joke
# 3          WA         KEXP       The Beachland Ballroom
# 4          WA         KEXP                     Velouria
# 5          WA         KEXP                    Clean Air
# 6          WA         KEXP                      Sunrise
# 7          WA         KEXP  Marching Bands of Manhattan
# 8          WA         KEXP              Nighttime Drive
# 9          WA         KEXP                  Come Around
# 10         WA         KEXP        Less Yes's, More No's
# 11         WA         KEXP                      Goodbye
# 12         WA         KEXP                 Unbelievable
# 13         WA         KEXP                      The Rat
# 14         WA         KEXP     You Dropped A Bomb On Me
#
#               trackartist                                         trackalbum  \
# 0            Big Gigantic                                     Free Your Mind
# 1          Run The Jewels                                    holy calamafuck
# 2          Brandi Carlile                                           The Joke
# 3                   IDLES                             The Beachland Ballroom
# 4                  Pixies                                          Bossanova
# 5             Hand Habits                                          Fun House
# 6   Explosions In The Sky  Big Bend (An Original Soundtrack for Public Te...
# 7     Death Cab for Cutie                        Marching Bands of Manhattan
# 8                 Jay Som                                            Anak Ko
# 9                  Breeze                                            Only Up
# 10              Busdriver                                  RoadKill Overcoat
# 11            The Sundays                                              Blind
# 12                    EMF                                    Le 100 Sexy Hit
# 13            The Walkmen                                      Bows + Arrows
# 14           The Gap Band                    Gap Gold - Best Of The Gap Band
#
#                                           trackstyles  \
# 0                                             Hip Hop
# 1                                                 NaN
# 2           Pop Rock,Rock & Roll,Country Rock,Country
# 3                                                 NaN
# 4                                          Indie Rock
# 5                                                 NaN
# 6                                Post Rock,Soundtrack
# 7                                          Indie Rock
# 8                          Indie Rock,Lo-Fi,Indie Pop
# 9       Post-Punk,Brit Pop,Alternative Rock,Dream Pop
# 10                                           Abstract
# 11                                         Indie Rock
# 12  Alternative Rock,Ballad,Brit Pop,Hip Hop,House...
# 13                                         Indie Rock
# 14                                               Funk
#
#                 trackmp3filename  captureyear  capturemonth  captureday  \
# 0   KEXP2021_10_25_T19_59_19.mp3         2021            10          25
# 1   KEXP2021_10_26_T11_12_56.mp3         2021            10          26
# 2   KEXP2021_10_26_T12_19_42.mp3         2021            10          26
# 3   KEXP2021_10_26_T12_50_29.mp3         2021            10          26
# 4   KEXP2021_10_27_T10_19_23.mp3         2021            10          27
# 5   KEXP2021_10_27_T10_37_45.mp3         2021            10          27
# 6   KEXP2021_10_27_T11_31_40.mp3         2021            10          27
# 7   KEXP2021_10_27_T12_05_38.mp3         2021            10          27
# 8   KEXP2021_10_27_T12_28_13.mp3         2021            10          27
# 9   KEXP2021_10_27_T12_31_57.mp3         2021            10          27
# 10  KEXP2021_10_27_T12_38_08.mp3         2021            10          27
# 11  KEXP2021_11_03_T10_47_40.mp3         2021            11           3
# 12  KEXP2021_11_03_T11_23_07.mp3         2021            11           3
# 13  KEXP2021_11_03_T11_52_22.mp3         2021            11           3
# 14  KEXP2021_11_03_T14_51_08.mp3         2021            11           3
#
#     capturehour  captureminute  capturesecond
# 0            19             59             19
# 1            11             12             56
# 2            12             19             42
# 3            12             50             29
# 4            10             19             23
# 5            10             37             45
# 6            11             31             40
# 7            12              5             38
# 8            12             28             13
# 9            12             31             57
# 10           12             38              8
# 11           10             47             40
# 12           11             23              7
# 13           11             52             22
# 14           14             51              8

# %%
song_csv_fold = os.path.join(workindir, 'WASH SONG LOGS')
os.mkdir(song_csv_fold)

# %%
for station in wash_callsign_folds:
    pathtostationfold = os.path.join(workindir,
                                    "WASH STATIONS",
                                     station)
    newsongcsv = os.path.join(pathtostationfold,
                             f'{station}_TrackLog_2021_11_03.csv')
    stationfolditems = os.listdir(pathtostationfold)
    fullpathitems = []
    for item in stationfolditems:
        fullpathitems.append(os.path.join(pathtostationfold,
                                         item))
    if newsongcsv in fullpathitems:
        copyfile(newsongcsv,
                 os.path.join(workindir,
                              "WASH SONG LOGS",
                              f'{station}_TrackLog_2021_11_03.csv'))

# %%
newsongcsv
# Out:
# '/Users/michaelfelzan/Desktop/GEO FM/WASH STATIONS/KCMS/KCMS_SONGLOG.csv'

# %%
print(workindir)
# Out:
# /Users/michaelfelzan/Desktop/GEO FM

# %%
for station in wash_callsign_folds:
    pathtofold = os.path.join(workindir,
                              'WASH SONG LOGS')
SONGconcatCSV = os.path.join(pathtofold,
                            "CONCAT_TRACKLOG_2021_11_03.csv") 
allFiles = glob.glob(pathtofold + "/*.csv")
allFiles.sort()
with open(SONGconcatCSV, 'wb') as outfile:
        for i, fname in enumerate(allFiles):
            with open(fname, 'rb') as infile:
                if i != 0:
                    infile.readline()  # Throw away header on all but first file
            # Block copy rest of file from input to output without parsing
                shutil.copyfileobj(infile, outfile)

print("     *~*~~~~~**~~~~~~~~~~~~~~**~*~*\n"
      "All SONG PLAY LOG CSVs (that exist) have"+
      "\n      been successfully merged together"
      "\n  *~*~~~~~**~~~~~~~~~~~~~~**~*~*")
# Out:
#      *~*~~~~~**~~~~~~~~~~~~~~**~*~*
# All SONG PLAY LOG CSVs (that exist) have
#       been successfully merged together
#   *~*~~~~~**~~~~~~~~~~~~~~**~*~*

# %%
concat_tracklog = r'/Users/michaelfelzan/Desktop/GEO FM/WASH SONG LOGS/CONCAT_TRACKLOG_2021_11_03.csv'

# %%
testlis = []
gospel = 'Gospel'
hmm = gospel.split(',')
for item in hmm:
    testlis.append(item)
testlis
# Out:
# ['Gospel']

# %%
hmm
# Out:
# ['Gospel']

# %%
unique_styles = []

with open(concat_tracklog, 'r') as read_obj:
    csv_reader = reader(read_obj)
    header = next(csv_reader)
    if header != None:
        for row in csv_reader:
            initvalue = row[5]
            splitinit = initvalue.split(',')
            for item in splitinit:
                if item not in unique_styles:
                    unique_styles.append(item)

# %%
unique_styles
# Out:
# ['Gospel',
#  'Country',
#  'Country Rock',
#  'Religious',
#  'Easy Listening',
#  '',
#  'Blues Rock',
#  'Stoner Rock',
#  'Psychedelic Rock',
#  'Indie Rock',
#  'No Wave',
#  'Surf',
#  'Norteño',
#  'Son',
#  'Ranchera',
#  'Mariachi',
#  'Vocal',
#  'Corrido',
#  'Cumbia',
#  'Tejano',
#  'Rock & Roll',
#  'Southern Rock',
#  'Hard Rock',
#  'Classic Rock',
#  'Prog Rock',
#  'Soft Rock',
#  'Pop Rock',
#  'Heavy Metal',
#  'Post Bop',
#  'Latin Jazz',
#  'Bop',
#  'Hard Bop',
#  'Contemporary Jazz',
#  'Hip Hop',
#  'Post Rock',
#  'Soundtrack',
#  'Lo-Fi',
#  'Indie Pop',
#  'Post-Punk',
#  'Brit Pop',
#  'Alternative Rock',
#  'Dream Pop',
#  'Abstract',
#  'Ballad',
#  'House',
#  'Pop Rap',
#  'RnB/Swing',
#  'Synth-pop',
#  'UK Garage',
#  'Funk',
#  'Art Rock',
#  'Baroque',
#  'Classical',
#  'Romantic',
#  'Neo-Classical',
#  'Modern',
#  'Folk Rock',
#  'Emo',
#  'Pop Punk',
#  'Post-Hardcore',
#  'Metalcore',
#  'Score',
#  'Downtempo',
#  'Ambient',
#  'Drone',
#  'Experimental',
#  'New Age',
#  'Power Pop',
#  'Acoustic',
#  'Dance-pop',
#  'Soul',
#  'Electro',
#  'Europop',
#  'Progressive House',
#  'Soul-Jazz',
#  'Music Hall',
#  'Novelty',
#  'Comedy',
#  'Psychedelic',
#  'Big Band',
#  'Smooth Jazz',
#  'Hi NRG',
#  'Happy Hardcore',
#  'Disco',
#  'Ragga HipHop',
#  'Techno',
#  'Euro House',
#  'Italodance',
#  'Swing',
#  'African',
#  'Leftfield',
#  'Afrobeat',
#  'Jazz-Funk',
#  'Bossanova',
#  'Western Swing',
#  'Honky Tonk',
#  'Broken Beat',
#  'Deep House',
#  'Musical',
#  'Conscious',
#  'Contemporary R&B',
#  'Tropical House',
#  'Electro House',
#  'Grime']
